# %% [markdown]
# # EDA on jobtech API

# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:   
        print(f"{hit['headline']}, {hit['employer']['name']}")

if __name__ == "__main__":
    query = ' lärare uppsala'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
#query = 'lärare uppsala'
#example_search_loop_through_hits(query)
# Out:
# Vill du arbeta med våra elever i åk 4-9?, Gluntens Montessoriskola AB
# Vill du arbeta med våra elever i åk 4-9?, Gluntens Montessoriskola AB
# Vill du arbeta med våra elever i åk 4-9?, Gluntens Montessoriskola AB
# Vill du arbeta med våra elever i åk 4-9?, Gluntens Montessoriskola AB
# Förskollärare, vikariat 50%, ev utökas i januari till 80%, C Företaget Barnomsorg Bull ekonomisk förening
# Lärare åk F-3 till Rosendals skola (tidsbegränsad), Uppsala kommun
# Lärare åk 4-6 - Storvretaskolan, Uppsala kommun
# Lärare NO, teknik och matematik - Gränbyskolan, Uppsala kommun
# Lärare i idrott och hälsa - Stavby skola, Uppsala kommun
# Lärare åk 5 - Liljeforsskolan, Uppsala kommun
# Lärare F-3 - Östra Stenhagenskolan, Uppsala kommun
# Timvikarie grundskola, Jensen education Aktiebolag
# Lärare i säkerhetstjänst, Försvarsmakten
# Yrkeslärare Byggnadsplåtslagare  Movant Uppsala, AcadeMedia Support AB
# Jobba som mellanstadielärare på Sveriges mest personliga bemanningsföretag!, PersonalExpressen AB
# Jobba som lågstadielärare på Sveriges mest personliga bemanningsföretag!, PersonalExpressen AB
#
# Number of hits = 16

# %%
example_search_return_number_of_hits(query)
# Out:
# Number of hits = 16

# %%
search_params = {'q': query, 'limit': 100}
json_response = _get_ads(search_params)
type(json_response)
# Out:
# dict

# %%
json_response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
len(json_response.get("hits"))
json_response.get("hits")
# Out:
# [{'relevance': 1.0,
#   'id': '31487342',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31487342',
#   'logo_url': None,
#   'headline': 'Vill du arbeta med våra elever i åk 4-9?',
#   'application_deadline': '2026-09-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Vi har lediga tjänster i Svenska, Bild, Matematik och NO.\nVi söker dig som är utbildad lärare i något eller några av ovan nämnda ämnen och som vill arbeta med våra elever i åk 4-9. Ämnena går att kombinera till olika tjänster. Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. \nDet är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.\nDu är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. \nVi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.\nI en av tjänsterna är du ansvarslärare för en klass, åk 7-9.\nTjänsterna är vikariat på olika % med start från ca 12 oktober t o m februari/mars 2027.\nDin ansökan ska innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.\nGod svenska i tal och skrift är ett krav.\nTillträde i oktober.\nMånadslön enligt överenskommelse.\nVi tillämpar 6 månaders provanställning.\nVälkommen med din ansökan redan idag! \nDå urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. \nSista ansökningsdag 2026-09-30\nGluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.',
#    'text_formatted': '<p><strong>Vi har lediga tjänster i Svenska, Bild, Matematik och NO.</strong></p><p>Vi söker dig som är <strong>utbildad</strong> lärare i något eller några av ovan nämnda ämnen och som vill arbeta med våra elever i åk 4-9. Ämnena går att kombinera till olika tjänster. Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. </p><p>Det är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.</p><p>Du är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. </p><p>Vi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.</p><p>I en av tjänsterna är du ansvarslärare för en klass, åk 7-9.</p><p>Tjänsterna är vikariat på olika % med start från ca 12 oktober t o m februari/mars 2027.</p><p>Din ansökan <strong>ska</strong> innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.</p><p>God svenska i tal och skrift är ett krav.</p><p>Tillträde i oktober.</p><p>Månadslön enligt överenskommelse.</p><p>Vi tillämpar 6 månaders provanställning.</p><p><strong>Välkommen med din ansökan redan idag! </strong></p><p>Då urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. </p><p><strong>Sista ansökningsdag 2026-09-30</strong></p><p><em>Gluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.</em></p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'sTu5_NBQ_udq',
#    'label': 'Tidsbegränsad anställning',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'Xj7x_7yZ_jEn',
#    'label': '3 månader – upp till 6 månader',
#    'legacy_ams_taxonomy_id': '3'},
#   'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#    'label': 'Deltid',
#    'legacy_ams_taxonomy_id': '2'},
#   'scope_of_work': {'min': 0, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'www.glunten.se',
#    'organization_number': '5592659667',
#    'name': 'Gluntens Montessoriskola AB',
#    'workplace': 'Gluntens Montessoriskola AB'},
#   'application_details': {'information': None,
#    'reference': 'Lärare 4-9',
#    'email': 'ansokan@glunten.se',
#    'via_af': False,
#    'url': None,
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'wypk_7S7_snv',
#    'label': 'Ämneslärare, 7-9',
#    'legacy_ams_taxonomy_id': None},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Ekeby Bruk 10 A',
#    'postcode': '75263',
#    'city': 'Uppsala',
#    'coordinates': [17.6081486630901, 59.8478585703143]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Ekeby Bruk 10 A',
#     'postcode': '75263',
#     'city': 'Uppsala',
#     'coordinates': [17.6081486630901, 59.8478585703143]}],
#   'must_have': {'skills': [],
#    'languages': [{'weight': 10,
#      'concept_id': 'zSLA_vw2_FXN',
#      'label': 'Svenska',
#      'legacy_ams_taxonomy_id': '502'}],
#    'work_experiences': [],
#    'education': [{'weight': 10,
#      'concept_id': 'tFCz_HSa_jwW',
#      'label': 'Pedagogik och lärarutbildning',
#      'legacy_ams_taxonomy_id': '4'}],
#    'education_level': [{'weight': 10,
#      'concept_id': 'asZm_TEQ_Srk',
#      'label': 'Eftergymnasial utbildning två år eller längre',
#      'legacy_ams_taxonomy_id': '6'}]},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 5,
#      'concept_id': 'wypk_7S7_snv',
#      'label': 'Ämneslärare, 7–9',
#      'legacy_ams_taxonomy_id': None}],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': 'Mikaela Mosca',
#     'description': None,
#     'email': 'rektor@glunten.se',
#     'telephone': None,
#     'contact_type': 'Rektor'},
#    {'name': 'Guillermo Garroz',
#     'description': None,
#     'email': 'guillermo.garroz@glunten.se',
#     'telephone': '070-6442496',
#     'contact_type': 'Sveriges Lärare'}],
#   'publication_date': '2026-09-17T09:01:55',
#   'last_publication_date': '2026-09-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1789628515798},
#  {'relevance': 1.0,
#   'id': '31487331',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31487331',
#   'logo_url': None,
#   'headline': 'Vill du arbeta med våra elever i åk 4-9?',
#   'application_deadline': '2026-09-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Vi har lediga tjänster i Svenska, Bild, Matematik och NO.\nVi söker dig som är utbildad lärare i något eller några av ovan nämnda ämnen och som vill arbeta med våra elever i åk 4-9. Ämnena går att kombinera till olika tjänster. Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. \nDet är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.\nDu är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. \nVi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.\nI en av tjänsterna är du ansvarslärare för en klass, åk 7-9.\nTjänsterna är vikariat på olika % med start från ca 12 oktober t o m februari/mars 2027.\nDin ansökan ska innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.\nGod svenska i tal och skrift är ett krav.\nTillträde i oktober.\nMånadslön enligt överenskommelse.\nVi tillämpar 6 månaders provanställning.\nVälkommen med din ansökan redan idag! \nDå urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. \nSista ansökningsdag 2026-09-30\nGluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.',
#    'text_formatted': '<p><strong>Vi har lediga tjänster i Svenska, Bild, Matematik och NO.</strong></p><p>Vi söker dig som är <strong>utbildad</strong> lärare i något eller några av ovan nämnda ämnen och som vill arbeta med våra elever i åk 4-9. Ämnena går att kombinera till olika tjänster. Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. </p><p>Det är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.</p><p>Du är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. </p><p>Vi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.</p><p>I en av tjänsterna är du ansvarslärare för en klass, åk 7-9.</p><p>Tjänsterna är vikariat på olika % med start från ca 12 oktober t o m februari/mars 2027.</p><p>Din ansökan <strong>ska</strong> innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.</p><p>God svenska i tal och skrift är ett krav.</p><p>Tillträde i oktober.</p><p>Månadslön enligt överenskommelse.</p><p>Vi tillämpar 6 månaders provanställning.</p><p><strong>Välkommen med din ansökan redan idag! </strong></p><p>Då urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. </p><p><strong>Sista ansökningsdag 2026-09-30</strong></p><p><em>Gluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.</em></p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'sTu5_NBQ_udq',
#    'label': 'Tidsbegränsad anställning',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'Xj7x_7yZ_jEn',
#    'label': '3 månader – upp till 6 månader',
#    'legacy_ams_taxonomy_id': '3'},
#   'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#    'label': 'Deltid',
#    'legacy_ams_taxonomy_id': '2'},
#   'scope_of_work': {'min': 0, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'www.glunten.se',
#    'organization_number': '5592659667',
#    'name': 'Gluntens Montessoriskola AB',
#    'workplace': 'Gluntens Montessoriskola AB'},
#   'application_details': {'information': None,
#    'reference': 'Lärare 4-9',
#    'email': 'ansokan@glunten.se',
#    'via_af': False,
#    'url': None,
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'S9LC_4m4_yza',
#    'label': 'Grundlärare, 4-6',
#    'legacy_ams_taxonomy_id': None},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Ekeby Bruk 10 A',
#    'postcode': '75263',
#    'city': 'Uppsala',
#    'coordinates': [17.6081486630901, 59.8478585703143]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Ekeby Bruk 10 A',
#     'postcode': '75263',
#     'city': 'Uppsala',
#     'coordinates': [17.6081486630901, 59.8478585703143]}],
#   'must_have': {'skills': [],
#    'languages': [{'weight': 10,
#      'concept_id': 'zSLA_vw2_FXN',
#      'label': 'Svenska',
#      'legacy_ams_taxonomy_id': '502'}],
#    'work_experiences': [],
#    'education': [{'weight': 10,
#      'concept_id': 'tFCz_HSa_jwW',
#      'label': 'Pedagogik och lärarutbildning',
#      'legacy_ams_taxonomy_id': '4'}],
#    'education_level': [{'weight': 10,
#      'concept_id': 'asZm_TEQ_Srk',
#      'label': 'Eftergymnasial utbildning två år eller längre',
#      'legacy_ams_taxonomy_id': '6'}]},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 5,
#      'concept_id': 'S9LC_4m4_yza',
#      'label': 'Grundlärare, 4-6',
#      'legacy_ams_taxonomy_id': None}],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': 'Mikaela Mosca',
#     'description': None,
#     'email': 'rektor@glunten.se',
#     'telephone': None,
#     'contact_type': 'Rektor'},
#    {'name': 'Guillermo Garroz',
#     'description': None,
#     'email': 'guillermo.garroz@glunten.se',
#     'telephone': '070-6442496',
#     'contact_type': 'Sveriges Lärare'}],
#   'publication_date': '2026-09-17T08:59:46',
#   'last_publication_date': '2026-09-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1789628386281},
#  {'relevance': 1.0,
#   'id': '31487217',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31487217',
#   'logo_url': None,
#   'headline': 'Vill du arbeta med våra elever i åk 4-9?',
#   'application_deadline': '2026-10-17T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Vi söker en lärare i Idrott för åk 4-9.\nVi söker dig som är utbildad lärare i Idrott och som vill arbeta med våra elever i åk 4-9. \nHar du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. \nDet är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.\nDu är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. \nVi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.\nTjänsten är en visstidstjänst på 50% ht26 och 100% vt27.\nI tjänsten under vt27 är du ansvarslärare för en klass, åk 7-9.\nDin ansökan ska innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.\nGod svenska i tal och skrift är ett krav.\nTillträde 261102\nMånadslön enligt överenskommelse.\nVi tillämpar 6 månaders provanställning.\n\n\nVälkommen med din ansökan redan idag! \nDå urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. \nSista ansökningsdag 2026-09-30\nGluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.',
#    'text_formatted': '<p><strong>Vi söker en lärare i Idrott för åk 4-9.</strong></p><p>Vi söker dig som är <strong>utbildad</strong> lärare i Idrott och som vill arbeta med våra elever i åk 4-9. </p><p>Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. </p><p>Det är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.</p><p>Du är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. </p><p>Vi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.</p><p>Tjänsten är en visstidstjänst på 50% ht26 och 100% vt27.</p><p>I tjänsten under vt27 är du ansvarslärare för en klass, åk 7-9.</p><p>Din ansökan <strong>ska</strong> innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.</p><p>God svenska i tal och skrift är ett krav.</p><p>Tillträde 261102</p><p>Månadslön enligt överenskommelse.</p><p>Vi tillämpar 6 månaders provanställning.</p><p><br></p><p><strong>Välkommen med din ansökan redan idag! </strong></p><p>Då urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. </p><p><strong>Sista ansökningsdag 2026-09-30</strong></p><p><em>Gluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.</em></p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'sTu5_NBQ_udq',
#    'label': 'Tidsbegränsad anställning',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'gJRb_akA_95y',
#    'label': '6 månader – upp till 12 månader',
#    'legacy_ams_taxonomy_id': '0'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'www.glunten.se',
#    'organization_number': '5592659667',
#    'name': 'Gluntens Montessoriskola AB',
#    'workplace': 'Gluntens Montessoriskola AB'},
#   'application_details': {'information': None,
#    'reference': 'Lärare idrott',
#    'email': 'ansokan@glunten.se',
#    'via_af': False,
#    'url': None,
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'wypk_7S7_snv',
#    'label': 'Ämneslärare, 7-9',
#    'legacy_ams_taxonomy_id': None},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Ekeby Bruk 10 A',
#    'postcode': '75263',
#    'city': 'Uppsala',
#    'coordinates': [17.6081486630901, 59.8478585703143]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Ekeby Bruk 10 A',
#     'postcode': '75263',
#     'city': 'Uppsala',
#     'coordinates': [17.6081486630901, 59.8478585703143]}],
#   'must_have': {'skills': [],
#    'languages': [{'weight': 10,
#      'concept_id': 'zSLA_vw2_FXN',
#      'label': 'Svenska',
#      'legacy_ams_taxonomy_id': '502'}],
#    'work_experiences': [],
#    'education': [{'weight': 10,
#      'concept_id': 'tFCz_HSa_jwW',
#      'label': 'Pedagogik och lärarutbildning',
#      'legacy_ams_taxonomy_id': '4'}],
#    'education_level': [{'weight': 10,
#      'concept_id': 'asZm_TEQ_Srk',
#      'label': 'Eftergymnasial utbildning två år eller längre',
#      'legacy_ams_taxonomy_id': '6'}]},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': 'Mikaela  Mosca',
#     'description': None,
#     'email': 'rektor@glunten.se',
#     'telephone': None,
#     'contact_type': 'Rektor'},
#    {'name': 'Guillermo Garroz',
#     'description': None,
#     'email': 'guillermo.garroz@glunten.se',
#     'telephone': '070-6442496',
#     'contact_type': 'Sveriges Lärare'}],
#   'publication_date': '2026-09-17T08:46:20',
#   'last_publication_date': '2026-10-17T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1789627580676},
#  {'relevance': 1.0,
#   'id': '31487176',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31487176',
#   'logo_url': None,
#   'headline': 'Vill du arbeta med våra elever i åk 4-9?',
#   'application_deadline': '2026-09-30T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Vi söker en lärare i Idrott för åk 4-9.\nVi söker dig som är utbildad lärare i Idrott och som vill arbeta med våra elever i åk 4-9. \nHar du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. \nDet är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.\nDu är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. \nVi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.\nTjänsten är en visstidstjänst på 50% ht26 och 100% vt27.\nI tjänsten under vt27 är du ansvarslärare för en klass, åk 7-9.\nDin ansökan ska innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.\nGod svenska i tal och skrift är ett krav.\nTillträde 261102\nMånadslön enligt överenskommelse.\nVi tillämpar 6 månaders provanställning.\n\n\nVälkommen med din ansökan redan idag! \nDå urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. \nSista ansökningsdag 2026-09-30\nGluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.',
#    'text_formatted': '<p><strong>Vi söker en lärare i Idrott för åk 4-9.</strong></p><p>Vi söker dig som är <strong>utbildad</strong> lärare i Idrott och som vill arbeta med våra elever i åk 4-9. </p><p>Har du montessoriutbildning eller arbetat med montessoripedagogiken ser vi det som ett plus. </p><p>Det är även meriterande om du har arbetat med elever med NPF och inkluderande pedagogik samt om du har arbetat i en mångkulturell miljö då vi värdesätter inkludering och mångfald.</p><p>Du är trygg i din lärar- och vuxenroll och har förmågan att möta varje elev individuellt. </p><p>Vi värdesätter en god pedagogisk förmåga och förståelse för människors olika förutsättningar att ta till sig kunskap. Du har en god samarbetsförmåga och relaterar till andra på ett lyhört och smidigt sätt samtidigt som du är duktig på att bygga och bibehålla relationer med elever, kollegor och föräldrar.</p><p>Tjänsten är en visstidstjänst på 50% ht26 och 100% vt27.</p><p>I tjänsten under vt27 är du ansvarslärare för en klass, åk 7-9.</p><p>Din ansökan <strong>ska</strong> innehålla ditt CV, ett personligt brev och en kopia på din lärarlegitimation.</p><p>God svenska i tal och skrift är ett krav.</p><p>Tillträde 261102</p><p>Månadslön enligt överenskommelse.</p><p>Vi tillämpar 6 månaders provanställning.</p><p><br></p><p><strong>Välkommen med din ansökan redan idag! </strong></p><p>Då urval och intervjuer sker löpande kan tjänsterna komma att tillsättas före sista ansökningsdag. </p><p><strong>Sista ansökningsdag 2026-09-30</strong></p><p><em>Gluntens Montessoriskola är en fristående skola i Uppsala. Vi har drygt 85 medarbetare och ca 600 barn/elever (inklusive barn i förskolan). Barnen kan börja i förskolan som ettåringar och vara kvar i vår skola till och med årskurs 9. Vi har motiverade elever och engagerade föräldrar. Glunten är en arbetsplats med många engagerade, flexibla och kompetenta medarbetare.</em></p>',
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'sTu5_NBQ_udq',
#    'label': 'Tidsbegränsad anställning',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'gJRb_akA_95y',
#    'label': '6 månader – upp till 12 månader',
#    'legacy_ams_taxonomy_id': '0'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'www.glunten.se',
#    'organization_number': '5592659667',
#    'name': 'Gluntens Montessoriskola AB',
#    'workplace': 'Gluntens Montessoriskola AB'},
#   'application_details': {'information': None,
#    'reference': 'Lärare idrott',
#    'email': 'ansokan@glunten.se',
#    'via_af': False,
#    'url': None,
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'S9LC_4m4_yza',
#    'label': 'Grundlärare, 4-6',
#    'legacy_ams_taxonomy_id': None},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'Ekeby Bruk 10 A',
#    'postcode': '75263',
#    'city': 'Uppsala',
#    'coordinates': [17.6081486630901, 59.8478585703143]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Ekeby Bruk 10 A',
#     'postcode': '75263',
#     'city': 'Uppsala',
#     'coordinates': [17.6081486630901, 59.8478585703143]}],
#   'must_have': {'skills': [],
#    'languages': [{'weight': 10,
#      'concept_id': 'zSLA_vw2_FXN',
#      'label': 'Svenska',
#      'legacy_ams_taxonomy_id': '502'}],
#    'work_experiences': [],
#    'education': [{'weight': 10,
#      'concept_id': 'tFCz_HSa_jwW',
#      'label': 'Pedagogik och lärarutbildning',
#      'legacy_ams_taxonomy_id': '4'}],
#    'education_level': [{'weight': 10,
#      'concept_id': 'asZm_TEQ_Srk',
#      'label': 'Eftergymnasial utbildning två år eller längre',
#      'legacy_ams_taxonomy_id': '6'}]},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 5,
#      'concept_id': 'S9LC_4m4_yza',
#      'label': 'Grundlärare, 4-6',
#      'legacy_ams_taxonomy_id': None}],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [{'name': 'Mikaela  Mosca',
#     'description': None,
#     'email': 'rektor@glunten.se',
#     'telephone': None,
#     'contact_type': 'Rektor'},
#    {'name': 'Guillermo Garroz',
#     'description': None,
#     'email': 'guillermo.garroz@glunten.se',
#     'telephone': '070-6442496',
#     'contact_type': 'Sveriges Lärare'}],
#   'publication_date': '2026-09-17T08:42:15',
#   'last_publication_date': '2026-09-30T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1789627335666},
#  {'relevance': 1.0,
#   'id': '31486752',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31486752',
#   'logo_url': None,
#   'headline': 'Förskollärare, vikariat 50%, ev utökas i januari till 80%',
#   'application_deadline': '2026-10-17T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Ekeby förskola söker en legitimerad förskollärare till ett vikariat på 50 %, med möjlighet att tjänsten utökas till cirka 80 % från januari. Rekrytering sker löpande och tjänsten kan tillsättas omgående.\nVill du arbeta på en liten och familjär förskola där du får vara nära barnen, påverka utbildningen och utvecklas tillsammans med engagerade kollegor? Vill du ha en arbetsplats där dina idéer tas tillvara och där ledningen finns nära verksamheten?\nDå kan Ekeby förskola vara rätt arbetsplats för dig!\nOm Ekeby förskola\nEkeby förskola är en liten och personlig förskola där trygghet, delaktighet, omsorg och lärande är grunden för vår verksamhet. Här ska varje barn känna sig sett, lyssnat på och betydelsefullt.\nVårt arbetssätt präglas av Montessoripedagogik med inspiration från Reggio Emilia och utomhuspedagogik. Vi ser barnet som aktivt, nyfiket och kompetent och lägger stor vikt vid självständighet, utforskande, kreativitet och lärande i samspel med andra.\nVi använder vårt närområde med parker, skog och natur som en naturlig del av utbildningen och tycker om att flytta undervisningen utanför förskolans väggar.\nHos oss får du arbeta i en verksamhet där det finns möjlighet att påverka på riktigt. Vi vill ha pedagoger som tänker, reflekterar, kommer med idéer och tillsammans med kollegor och ledning vill utveckla utbildningen utifrån barnens bästa.\nVem söker vi?\nVi söker dig som är legitimerad förskollärare eller legitimerad lärare med behörighet för arbete i förskolan. Du är väl förtrogen med förskolans läroplan och kan omsätta uppdraget i den pedagogiska vardagen.\nDu är nyfiken på barns lärprocesser och lärmiljöer och ser varje barns individuella förutsättningar, behov och möjligheter. Du använder pedagogisk dokumentation för att följa, reflektera över och utveckla undervisningen och har god digital kompetens.\nFör oss är det viktigt att du:\när engagerad, ansvarstagande och initiativrik\ntycker om pedagogiska diskussioner och kollegialt lärande\nhar god samarbetsförmåga och samtidigt kan arbeta självständigt\när lyhörd och flexibel och ser möjligheter i vardagen\nhar ett varmt och professionellt bemötande\nhar god kommunikativ förmåga och skapar förtroendefulla relationer med barn, vårdnadshavare och kollegor\nvill vara med och utveckla verksamheten – inte bara förvalta det vi redan gör.\n\n\n\nDitt uppdrag som förskollärare\nSom förskollärare har du en viktig roll i att tillsammans med arbetslaget skapa en trygg, omsorgsfull, lustfylld och lärorik utbildning.\nDu planerar, genomför, dokumenterar, följer upp och utvecklar undervisningen utifrån aktuella styrdokument. Med läroplanen som grund väljer och utvecklar du innehåll och arbetssätt utifrån barnens erfarenheter, intressen, behov och förutsättningar.\nDu leder de målstyrda processerna i undervisningen och bidrar till att barnen får möjlighet att utvecklas och utmanas vidare i sitt lärande. Du är samtidigt en närvarande pedagog som ser omsorg, lek, utveckling och lärande som en helhet.\nArbetet sker tillsammans med arbetslaget. Vi tror på att dela kunskap, reflektera tillsammans och ta ett gemensamt ansvar för att utveckla utbildningens kvalitet.\nVad erbjuder vi?\nHos oss får du en arbetsplats där engagemang, delaktighet och utveckling uppskattas. Vi vill att våra pedagoger ska kunna påverka sitt arbete och vara delaktiga i verksamhetens utveckling.\nC Företaget driver flera förskolor, vilket ger möjlighet till erfarenhetsutbyte, kollegialt lärande och fortsatt utveckling. Vår ambition är att ha kompetenta och engagerade medarbetare, god personaltäthet och en närvarande ledning som finns tillgänglig när verksamheten behöver stöd.\nVi söker dig som vill vara med och tänka nytt, utveckla och förbättra – alltid med barnets bästa i fokus.\nOm tjänsten\nTjänst: Förskollärare, vikariat\nOmfattning: 50 %\nMöjlighet till utökning: Tjänsten kan eventuellt utökas till cirka 80 % från januari\nTillträde: Omgående eller enligt överenskommelse\nArbetsp ...
#    'text_formatted': '<p>Ekeby förskola söker en legitimerad förskollärare till ett vikariat på 50 %, med möjlighet att tjänsten utökas till cirka 80 % från januari. Rekrytering sker löpande och tjänsten kan tillsättas omgående.</p><p>Vill du arbeta på en liten och familjär förskola där du får vara nära barnen, påverka utbildningen och utvecklas tillsammans med engagerade kollegor? Vill du ha en arbetsplats där dina idéer tas tillvara och där ledningen finns nära verksamheten?</p><p>Då kan Ekeby förskola vara rätt arbetsplats för dig!</p><p>Om Ekeby förskola</p><p>Ekeby förskola är en liten och personlig förskola där trygghet, delaktighet, omsorg och lärande är grunden för vår verksamhet. Här ska varje barn känna sig sett, lyssnat på och betydelsefullt.</p><p>Vårt arbetssätt präglas av Montessoripedagogik med inspiration från Reggio Emilia och utomhuspedagogik. Vi ser barnet som aktivt, nyfiket och kompetent och lägger stor vikt vid självständighet, utforskande, kreativitet och lärande i samspel med andra.</p><p>Vi använder vårt närområde med parker, skog och natur som en naturlig del av utbildningen och tycker om att flytta undervisningen utanför förskolans väggar.</p><p>Hos oss får du arbeta i en verksamhet där det finns möjlighet att påverka på riktigt. Vi vill ha pedagoger som tänker, reflekterar, kommer med idéer och tillsammans med kollegor och ledning vill utveckla utbildningen utifrån barnens bästa.</p><p>Vem söker vi?</p><p>Vi söker dig som är legitimerad förskollärare eller legitimerad lärare med behörighet för arbete i förskolan. Du är väl förtrogen med förskolans läroplan och kan omsätta uppdraget i den pedagogiska vardagen.</p><p>Du är nyfiken på barns lärprocesser och lärmiljöer och ser varje barns individuella förutsättningar, behov och möjligheter. Du använder pedagogisk dokumentation för att följa, reflektera över och utveckla undervisningen och har god digital kompetens.</p><p>För oss är det viktigt att du:</p><ul><li>är engagerad, ansvarstagande och initiativrik</li><li>tycker om pedagogiska diskussioner och kollegialt lärande</li><li>har god samarbetsförmåga och samtidigt kan arbeta självständigt</li><li>är lyhörd och flexibel och ser möjligheter i vardagen</li><li>har ett varmt och professionellt bemötande</li><li>har god kommunikativ förmåga och skapar förtroendefulla relationer med barn, vårdnadshavare och kollegor</li><li>vill vara med och utveckla verksamheten – inte bara förvalta det vi redan gör.</li></ul><p><br></p><p>Ditt uppdrag som förskollärare</p><p>Som förskollärare har du en viktig roll i att tillsammans med arbetslaget skapa en <strong>trygg, omsorgsfull, lustfylld och lärorik utbildning.</strong></p><p>Du planerar, genomför, dokumenterar, följer upp och utvecklar undervisningen utifrån aktuella styrdokument. Med läroplanen som grund väljer och utvecklar du innehåll och arbetssätt utifrån barnens erfarenheter, intressen, behov och förutsättningar.</p><p>Du leder de målstyrda processerna i undervisningen och bidrar till att barnen får möjlighet att utvecklas och utmanas vidare i sitt lärande. Du är samtidigt en närvarande pedagog som ser omsorg, lek, utveckling och lärande som en helhet.</p><p>Arbetet sker tillsammans med arbetslaget. Vi tror på att dela kunskap, reflektera tillsammans och ta ett gemensamt ansvar för att utveckla utbildningens kvalitet.</p><p>Vad erbjuder vi?</p><p>Hos oss får du en arbetsplats där engagemang, delaktighet och utveckling uppskattas. Vi vill att våra pedagoger ska kunna påverka sitt arbete och vara delaktiga i verksamhetens utveckling.</p><p>C Företaget driver flera förskolor, vilket ger möjlighet till erfarenhetsutbyte, kollegialt lärande och fortsatt utveckling. Vår ambition är att ha kompetenta och engagerade medarbetare, god personaltäthet och en närvarande ledning som finns tillgänglig när verksamheten behöver stöd.</p><p>Vi söker dig som vill vara med och tänka nytt, utveckla och förbättra – alltid med barnets bästa i fokus.</p><p>Om tjänsten</p><p>Tjänst ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'gro4_cWF_6D7',
#    'label': 'Vikariat',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'gJRb_akA_95y',
#    'label': '6 månader – upp till 12 månader',
#    'legacy_ams_taxonomy_id': '0'},
#   'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#    'label': 'Deltid',
#    'legacy_ams_taxonomy_id': '2'},
#   'scope_of_work': {'min': 0, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': 'http://www.ekebyforskola.se',
#    'organization_number': '7696083406',
#    'name': 'C Företaget Barnomsorg Bull ekonomisk förening',
#    'workplace': 'EKEBY FÖRSKOLA'},
#   'application_details': {'information': None,
#    'reference': 'Förskollärare',
#    'email': 'ekebyforskola@cforetaget.se',
#    'via_af': False,
#    'url': None,
#    'other': None},
#   'experience_required': True,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'rUcW_z9R_Qsv',
#    'label': 'Förskollärare',
#    'legacy_ams_taxonomy_id': '5714'},
#   'occupation_group': {'concept_id': '5ek3_Cgq_WeZ',
#    'label': 'Förskollärare',
#    'legacy_ams_taxonomy_id': '2343'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': 'KÖPENHAMNSGATAN 8-10',
#    'postcode': '75264',
#    'city': 'UPPSALA',
#    'coordinates': [17.60866333843836, 59.85213804905013]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'KÖPENHAMNSGATAN 8-10',
#     'postcode': '75264',
#     'city': 'UPPSALA',
#     'coordinates': [17.60866333843836, 59.85213804905013]}],
#   'must_have': {'skills': [{'weight': None,
#      'concept_id': '6Suw_3c1_47a',
#      'label': 'Förskollärarlegitimation',
#      'legacy_ams_taxonomy_id': '608920'}],
#    'languages': [],
#    'work_experiences': [{'weight': 10,
#      'concept_id': 'rUcW_z9R_Qsv',
#      'label': 'Förskollärare',
#      'legacy_ams_taxonomy_id': '5714'}],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-09-17T01:16:40',
#   'last_publication_date': '2026-10-17T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1789600600734},
#  {'relevance': 1.0,
#   'id': '31486280',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31486280',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/2120003005/logotyper/logo.png',
#   'headline': 'Lärare åk F-3 till Rosendals skola (tidsbegränsad)',
#   'application_deadline': '2026-09-22T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Välkommen till utbildningsförvaltningen. Vi erbjuder förskola, grundskola och gymnasieskola för barn och ungdomar mellan 0 och 20 år. Tillsammans jobbar vi mot målet att alla elever ska nå bästa möjliga kunskapsresultat. \r\n\r\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nVi kommer att begära utdrag ur belastningsregistret innan anställning kan erbjudas för tjänster som enligt lag kräver det. Du kan läsa mer om vilka områden som berörs på polisens hemsida.\r\n\r\n1 plats(er). \r\n\r\n\nVill du göra verklig skillnad för elevernas lärande? Hos oss får du undervisa eleverna i årskurs F-3 och samtidigt vara en viktig del av ett engagerat team. Låter detta intressant? Då ska du läsa vidare och söka tjänsten redan idag!\nRosendals skola är en F-9 skola med undervisning i den nybyggda skolan i Rosendal. Vi har fullt utrustade lokaler för att bedriva undervisning för cirka 700 elever i alla ämnen. Skolan ligger i västra delen av Rosendal och gränsar till Stadsskogen.\nVi arbetar med IBIS (inkluderande beteendestöd i skolan) för att skapa en positiv grundsyn bland alla på skolan. Vi har ett fullt utbyggt elevhälsoteam och jobbar mycket med värdegrund och trygghet.\xa0Högstadiet har fyra paralleller och F-6 växer. Till hösten är det två paralleller årskurs F- 5 och en parallell årskurs 6.\nBeskrivning av arbetsuppgifter\nI tjänsten ingår mentorskap och undervisning för våra elever i årskurs F-3. Du har ett nära samarbete och planerar samt utvärderar undervisningen tillsammans med din årskurskollega och även med de andra kollegorna årskurs F-3. Du kommer att ha nära och kontinuerlig kommunikation med vårdnadshavare.\nSom lärare ansvarar du för:\nPlanering, genomförande och uppföljning av undervisning enligt läroplanen.\nAtt skapa en strukturerad och trygg lärmiljö som främjar studiero och motivation.\nAtt möta elever på olika kunskapsnivåer genom varierade arbetssätt.\nDokumentation och bedömning av elevers kunskapsutveckling.\nSamarbete med kollegor, elevhälsa och vårdnadshavare.\n\nDenna tjänst är en tidsbegränsad anställning med tillträde omgående till och med mitten av vårterminen 2027.\xa0\nKvalifikationer\nVi söker dig som har svensk lärarlegitimation alternativt inväntar legitimation med behörighet att undervisa i årskurs F-3.\xa0För att lyckas i arbetet behöver du god kännedom om skolans styrdokument samt grundskolans läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. Har du erfarenhet av arbete med språkutvecklande arbetssätt ses det som meriterande.\nDu tar initiativ och sätter igång aktiviteter som skapar engagemang och bidrar till elevernas lärande. Du är flexibel och har lätt för att anpassa din undervisning efter förändrade förutsättningar. Vidare är du bra på att bygga förtroendefulla kontakter med elever, vårdnadshavare och kollegor, vilket skapar en trygg och inkluderande lärmiljö.\xa0\nUpplysningar\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Beatrice Strandin, biträdande rektor, 018-726 27 58.\nFacklig företrädare: Sveriges lärare, Elisa Eriksson, 018-727 81 00.\nHar du frågor gällande registrering av din ansökan, kontakta område rekrytering: 018-727 12 86.\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\nEn anställning hos Uppsala kommun kan komma att innebära en krigsplacering. \xa0\nLöneform: Månadslön.\r\nAnställningsform: Tidsbegränsad anställning.\r\nVaraktighet: 6 månader eller längre, tillträde: Omgående till och med mitten av VT27.',
# ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#    'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5591070213',
#    'name': 'PersonalExpressen AB',
#    'workplace': 'Uppsala'},
#   'application_details': {'information': None,
#    'reference': None,
#    'email': None,
#    'via_af': False,
#    'url': 'https://personalexpressen.weselect.com/p/71556-larare-copy',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'VZoJ_4oe_xyR',
#    'label': 'Lärare i grundskolan, årskurs 1-6',
#    'legacy_ams_taxonomy_id': '7750'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [None, None]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 5,
#      'concept_id': 'VZoJ_4oe_xyR',
#      'label': 'Lärare i grundskolan, årskurs 1–6',
#      'legacy_ams_taxonomy_id': '7750'}],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-08-13T17:47:25',
#   'last_publication_date': '2026-12-31T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1786636045736},
#  {'relevance': 1.0,
#   'id': '31350785',
#   'external_id': None,
#   'original_id': None,
#   'label': [],
#   'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31350785',
#   'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5591070213/logotyper/logo.png',
#   'headline': 'Jobba som lågstadielärare på Sveriges mest personliga bemanningsföretag!',
#   'application_deadline': '2026-12-31T23:59:59',
#   'number_of_vacancies': 1,
#   'description': {'text': 'Lärarkonsult – lågstadielärare med 60 000 kr/månad\nÄr du behörig lågstadielärare och vill arbeta som lärarkonsult på längre uppdrag – med möjlighet till en lön på upp till 60 000 kr per månad? Då vill vi gärna komma i kontakt med dig!\nPersonalExpressen Lärarbemanning söker engagerade och behöriga lågstadielärare som vill arbeta som lärarkonsulter på skolor runt om i Sverige.\nVi samarbetar med både kommunala och fristående skolor och får löpande in nya uppdrag. Som lärarkonsult får du möjlighet att arbeta på samma skola under en hel termin eller ett helt läsår, bygga relationer med elever och kollegor och bli en viktig del av skolans verksamhet.\nUpp till 60 000 kr per månad\nVi vet att erfarna och behöriga lärare är eftertraktade. Därför erbjuder vi upp till 60 000 kr per månad, beroende på uppdrag, behörighet och erfarenhet.\nHos oss får du möjlighet att kombinera en attraktiv lön med längre uppdrag, kontinuitet och nya erfarenheter.\nVi står för boende och resa\nVill du prova att arbeta på en annan ort? Som lärarkonsult hos oss kan du få möjlighet att ta uppdrag på andra platser i Sverige.\nOm uppdraget innebär arbete på annan ort står vi för boende och resa till och från uppdraget.\nDet innebär att du kan ta del av spännande läraruppdrag runt om i Sverige utan att själv behöva stå för kostnaderna för boende och resa.\nSom lärarkonsult gör du skillnad\nSom lågstadielärare spelar du en viktig roll i elevernas första skolår. Du får möjlighet att skapa en trygg, inspirerande och utvecklande lärmiljö där eleverna får bygga en stabil grund för sitt fortsatta lärande.\nUppdragen kan se olika ut beroende på skola och din behörighet. Det kan exempelvis handla om ett klassläraruppdrag eller undervisning i årskurs F–3.\nDu blir en viktig del av skolans ordinarie verksamhet och arbetar nära elever, kollegor och skolledning.\nVi söker dig som:\när utbildad och behörig lärare för förskoleklass och/eller årskurs 1–3\nvill arbeta som lärarkonsult\nhar ett genuint engagemang för elever och lärande\när trygg, tydlig och pedagogisk i din lärarroll\nhar lätt för att skapa goda relationer med elever, vårdnadshavare och kollegor\när ansvarstagande och lösningsorienterad\nsnabbt kan sätta dig in i en ny skolmiljö\nvill arbeta i längre uppdrag och följa elevernas utveckling över tid.\n\n\n\nDet här erbjuder vi\nHos PersonalExpressen Lärarbemanning får du mer än ett läraruppdrag. Vi vill att du ska känna dig uppskattad, trygg och väl omhändertagen genom hela uppdraget.\nVi erbjuder bland annat:\nupp till 60 000 kr i månadslön\ntermins- och läsårsuppdrag\nattraktiva anställningsvillkor\nmöjlighet att påverka vilken typ av uppdrag du är intresserad av\npersonlig kontakt och stöd genom hela uppdraget\nmöjlighet att utvecklas genom nya skolmiljöer och erfarenheter\nmöjlighet att arbeta på olika platser runt om i Sverige.\n\n\n\nVi tror på långsiktiga relationer och vill hitta rätt skola och rätt uppdrag för dig. Vårt mål är att du ska kunna fokusera på det viktigaste – undervisningen och elevernas utveckling – medan vi hjälper till med resten.\nÄr du redo för ditt nästa uppdrag som lärarkonsult?\nAttraktiv lön. Längre uppdrag. Nya möjligheter. Möjlighet att göra verklig skillnad.\nÄr du behörig lågstadielärare och vill ta nästa steg som lärarkonsult?\nSkicka in din ansökan till PersonalExpressen Lärarbemanning redan idag!\nVi ser fram emot att lära känna dig och hitta ditt nästa läraruppdrag.',
#    'text_formatted': '<p><strong>Lärarkonsult – lågstadielärare med 60 000 kr/månad</strong></p><p>Är du behörig lågstadielärare och vill arbeta som lärarkonsult på längre uppdrag – med möjlighet till en lön på upp till 60 000 kr per månad? Då vill vi gärna komma i kontakt med dig!</p><p><strong>PersonalExpressen Lärarbemanning söker engagerade och behöriga lågstadielärare som vill arbeta som lärarkonsulter</strong> på skolor runt om i Sverige.</p><p>Vi samarbetar med både kommunala och fristående skolor och får löpande in nya uppdrag. Som lärarkonsult får du möjlighet att arbeta på samma skola under en hel termin eller ett helt läsår, bygga relationer med elever och kollegor och bli en viktig del av skolans verksamhet.</p><p><strong>Upp till 60 000 kr per månad</strong></p><p><strong>Vi vet att erfarna och behöriga lärare är eftertraktade. Därför erbjuder vi upp till 60 000 kr per månad</strong>, beroende på uppdrag, behörighet och erfarenhet.</p><p>Hos oss får du möjlighet att kombinera <strong>en attraktiv lön med längre uppdrag, kontinuitet och nya erfarenheter</strong>.</p><p><strong>Vi står för boende och resa</strong></p><p>Vill du prova att arbeta på en annan ort? Som lärarkonsult hos oss kan du få möjlighet att ta uppdrag på andra platser i Sverige.</p><p>Om uppdraget innebär arbete på annan ort står vi för boende och resa till och från uppdraget.</p><p>Det innebär att du kan ta del av spännande läraruppdrag runt om i Sverige utan att själv behöva stå för kostnaderna för boende och resa.</p><p>Som lärarkonsult gör du skillnad</p><p>Som lågstadielärare spelar du en viktig roll i elevernas första skolår. Du får möjlighet att skapa en trygg, inspirerande och utvecklande lärmiljö där eleverna får bygga en stabil grund för sitt fortsatta lärande.</p><p>Uppdragen kan se olika ut beroende på skola och din behörighet. Det kan exempelvis handla om ett klassläraruppdrag eller undervisning i årskurs F–3.</p><p>Du blir en viktig del av skolans ordinarie verksamhet och arbetar nära elever, kollegor och skolledning.</p><p><strong>Vi söker dig som:</strong></p><ul><li>är utbildad och behörig lärare för förskoleklass och/eller årskurs 1–3</li><li>vill arbeta som <strong>lärarkonsult</strong></li><li>har ett genuint engagemang för elever och lärande</li><li>är trygg, tydlig och pedagogisk i din lärarroll</li><li>har lätt för att skapa goda relationer med elever, vårdnadshavare och kollegor</li><li>är ansvarstagande och lösningsorienterad</li><li>snabbt kan sätta dig in i en ny skolmiljö</li><li>vill arbeta i längre uppdrag och följa elevernas utveckling över tid.</li></ul><p><br></p><p><strong>Det här erbjuder vi</strong></p><p><strong>Hos PersonalExpressen Lärarbemanning får du mer än ett läraruppdrag. Vi vill att du ska känna dig uppskattad, trygg och väl omhändertagen genom hela uppdraget.</strong></p><p><strong>Vi erbjuder bland annat:</strong></p><ul><li><strong>upp till 60 000 kr i månadslön</strong></li><li>termins- och läsårsuppdrag</li><li>attraktiva anställningsvillkor</li><li>möjlighet att påverka vilken typ av uppdrag du är intresserad av</li><li>personlig kontakt och stöd genom hela uppdraget</li><li>möjlighet att utvecklas genom nya skolmiljöer och erfarenheter</li><li>möjlighet att arbeta på olika platser runt om i Sverige.</li></ul><p><br></p><p>Vi tror på långsiktiga relationer och vill hitta <strong>rätt skola och rätt uppdrag för dig</strong>. Vårt mål är att du ska kunna fokusera på det viktigaste – undervisningen och elevernas utveckling – medan vi hjälper till med resten.</p><p><strong>Är du redo för ditt nästa uppdrag som lärarkonsult?</strong></p><p><strong>Attraktiv lön. Längre uppdrag. Nya möjligheter. Möjlighet att göra verklig skillnad.</strong></p><p>Är du behörig lågstadielärare och vill ta nästa steg som lärarkonsult?</p><p><strong>Skicka in din ansökan till PersonalExpressen Lärarbemanning redan idag!</strong></p><p><strong>Vi ser fram emot att lära känna dig och hitta ditt nästa läraruppdrag.</strong>< ...
#    'company_information': None,
#    'needs': None,
#    'requirements': None,
#    'conditions': None},
#   'employment_type': {'concept_id': 'kpPX_CNN_gDU',
#    'label': 'Tillsvidareanställning (inkl. eventuell provanställning)',
#    'legacy_ams_taxonomy_id': None},
#   'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#    'label': 'Fast månads- vecko- eller timlön',
#    'legacy_ams_taxonomy_id': '1'},
#   'salary_description': None,
#   'duration': {'concept_id': 'a7uU_j21_mkL',
#    'label': 'Tills vidare',
#    'legacy_ams_taxonomy_id': '1'},
#   'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#    'label': 'Heltid',
#    'legacy_ams_taxonomy_id': '1'},
#   'scope_of_work': {'min': 100, 'max': 100},
#   'access': None,
#   'employer': {'phone_number': None,
#    'email': None,
#    'url': None,
#    'organization_number': '5591070213',
#    'name': 'PersonalExpressen AB',
#    'workplace': 'Uppsala'},
#   'application_details': {'information': None,
#    'reference': None,
#    'email': None,
#    'via_af': False,
#    'url': 'https://personalexpressen.weselect.com/p/71554-larare-copy',
#    'other': None},
#   'experience_required': False,
#   'access_to_own_car': False,
#   'driving_license_required': False,
#   'driving_license': None,
#   'occupation': {'concept_id': 'VZoJ_4oe_xyR',
#    'label': 'Lärare i grundskolan, årskurs 1-6',
#    'legacy_ams_taxonomy_id': '7750'},
#   'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#    'label': 'Grundskollärare',
#    'legacy_ams_taxonomy_id': '2341'},
#   'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#    'label': 'Pedagogik',
#    'legacy_ams_taxonomy_id': '15'},
#   'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#    'label': 'Arbete på plats'},
#   'workplace_address': {'municipality': 'Uppsala',
#    'municipality_code': '0380',
#    'municipality_concept_id': 'otaF_bQY_4ZD',
#    'region': 'Uppsala län',
#    'region_code': '03',
#    'region_concept_id': 'zBon_eET_fFU',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': None,
#    'city': None,
#    'coordinates': [None, None]},
#   'workplace_addresses': [{'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]}],
#   'must_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [],
#    'education': [],
#    'education_level': []},
#   'nice_to_have': {'skills': [],
#    'languages': [],
#    'work_experiences': [{'weight': 5,
#      'concept_id': 'VZoJ_4oe_xyR',
#      'label': 'Lärare i grundskolan, årskurs 1–6',
#      'legacy_ams_taxonomy_id': '7750'}],
#    'education': [],
#    'education_level': []},
#   'application_contacts': [],
#   'publication_date': '2026-08-13T17:18:25',
#   'last_publication_date': '2026-12-31T23:59:59',
#   'removed': False,
#   'removed_date': None,
#   'source_type': 'VIA_ANNONSERA',
#   'timestamp': 1786634305672}]

# %%
json_response.get("hits")[1].keys()
# Out:
# dict_keys(['relevance', 'id', 'external_id', 'original_id', 'label', 'webpage_url', 'logo_url', 'headline', 'application_deadline', 'number_of_vacancies', 'description', 'employment_type', 'salary_type', 'salary_description', 'duration', 'working_hours_type', 'scope_of_work', 'access', 'employer', 'application_details', 'experience_required', 'access_to_own_car', 'driving_license_required', 'driving_license', 'occupation', 'occupation_group', 'occupation_field', 'workplace_model', 'workplace_address', 'workplace_addresses', 'must_have', 'nice_to_have', 'application_contacts', 'publication_date', 'last_publication_date', 'removed', 'removed_date', 'source_type', 'timestamp'])

# %%
json_response.get("hits")[1]["headline"]
# Out:
# 'Vill du arbeta med våra elever i åk 4-9?'

# %%
json_response = _get_ads({'q': 'data engineer', 'limit': 100})
json_response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
json_response["hits"][-1]["headline"], json_response["hits"][-1]["employer"]["name"]
# Out:
# ('Senior Data & AI Platform Engineer till Axfood IT',
#  'Ants Akademiskt Nätverk av Tekniska Studenter AB')

# %%
def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))

# %%
query = "data engineer"
search_params = {'q': query, 'limit': 100}

# %%
json_response = _get_ads(search_params)
json_response
# Out:
# {'total': {'value': 81},
#  'positions': 94,
#  'query_time_in_millis': 6,
#  'result_time_in_millis': 66,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['data engineer'],
#   'trait': [],
#   'location': [],
#   'skill_must': [],
#   'occupation_must': [],
#   'trait_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'trait_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '31481035',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31481035',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5565688479/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-10-19T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vill du vara med och forma hur data används i Europas största utbildningsföretag?\nVi söker en Data Engineer som vill ta ansvar för både dataflödena och infrastrukturen de körs på. Hos oss får du vidareutveckla en modern dataplattform som används för analys, rapportering och verksamhetsutveckling inom hela AcadeMedia, och äga den automation som håller den i gång.\nDu blir en del av vårt centrala Data & Analytics-team. Vi är ett mindre team med stort ansvar och nära samarbete mellan teknik och verksamhet. Vi arbetar agilt i sprintar med en produktägare som prioriterar inkommande behov, vilket ger utrymme att arbeta fokuserat. Här får du stort utrymme att påverka, fatta beslut och driva arbetet framåt, från idé och arkitektur till implementering, driftsättning och långsiktig förvaltning.\nOm rollen\nDu vidareutvecklar vår lakehouse-plattform genom att ansluta nya källsystem och förvalta och förbättra det som redan finns. Rollen är bred och rör allt från inhämtning och transformation till infrastruktur och deployflöden, där Infrastructure as Code väger tyngre än i en typisk Data Engineer-roll.\nVi arbetar i Databricks och dbt på Azure, med infrastrukturen som kod i OpenTofu och Spacelift och deployflöden i GitHub Actions.\nDina huvudsakliga ansvarsområden\nAnsluta nya källsystem och bygga robusta dataflöden i Databricks och dbt, inklusive transformation, tester och dokumentation.\nBygga och underhålla våra dataleveranser till omgivande system.\nDriva och vidareutveckla våra IaC-lösningar samt automatisera CI/CD-flöden och infrastruktur.\nSäkra datakvalitet, observability, spårbarhet och säkerhet i nära samarbete med teamet.\nBidra i den dimensionella modelleringen.\nSamarbeta med analytiker, produktägare och verksamheten för att reda ut vad som faktiskt beh\növs innan lösningen byggs.\nDelta i tekniska vägval och vara med och forma plattformens utveckling framåt.\n\nVem är du?\nVi söker dig som har några års erfarenhet som Data Engineer, Analytics Engineer, plattformsingenjör eller backendutvecklare med starkt datafokus.\nDu trivs med att arbeta självständigt i ett mindre team och har en stark känsla av ägarskap. Du behöver inte ha alla svar från början, men du är van vid att undersöka alternativ, fatta välgrundade beslut och driva arbetet framåt utan detaljerad styrning.\nDin profil\nGoda kunskaper i SQL och Python, med vana vid moduler, beroendehantering och tester.\nErfarenhet av Databricks eller annan lakehouse-plattform\nErfarenhet av Infrastructure as Code (exempelvis Terraform eller OpenTofu) samt av CI/CD och versionshantering som ordinarie arbetssätt.\nGod blick för datakvalitet, driftsäkerhet och modern observability.\nSvenska och engelska i tal och skrift.\n\nDet är meriterande om du har erfarenhet av\nSpacelift eller annan IaC-orkestrering.\nDeclarative Automation Bundles (tidigare Databricks Asset Bundles).\nDbt eller motsvarande transformationsverktyg\nIntegrationer mot ERP- eller HR-system.\nLakehouse-arkitektur, data governance och Unity Catalog.\nPower BI och semantisk modellering.\n\nVi lägger stor vikt vid din nyfikenhet, din problemlösningsförmåga och din vilja att utvecklas tillsammans med oss.\nOm AcadeMedia\nAcadeMedia är Europas största utbildningsföretag med verksamhet i stora delar av Europa. Genom våra förskolor, grundskolor, gymnasier och vuxenutbildningar bidrar vi varje dag till att utveckla utbildning för barn, unga och vuxna. Data & Analytics-teamet arbetar centralt mot samtliga dessa verksamheter.\nÖvrig information\nTjänstens omfattning och placeringTjänsten är en tillsvidareanställning med 6 månaders provanställning. Kontoret ligger på Adolf Fredriks Kyrkogata i Stockholm.\xa0Urval sker löpande och tjänsten kan tillsättas innan sista ansökningsdatum.\nÄr du den vi söker?\xa0Välkommen att skicka in din ansökan innehållande CV\nHar du frågor om tjänsten, varmt välkommen att kontakta rekryterande chef, ylva.drugge@academedia.se\xa0\nVälkommen med din ansökan!\nVi har gjo ...
#     'text_formatted': '<p><strong>Vill du vara med och forma hur data används i Europas största utbildningsföretag?</strong></p><p>Vi söker en Data Engineer som vill ta ansvar för både dataflödena och infrastrukturen de körs på. Hos oss får du vidareutveckla en modern dataplattform som används för analys, rapportering och verksamhetsutveckling inom hela AcadeMedia, och äga den automation som håller den i gång.</p><p>Du blir en del av vårt centrala Data &amp; Analytics-team. Vi är ett mindre team med stort ansvar och nära samarbete mellan teknik och verksamhet. Vi arbetar agilt i sprintar med en produktägare som prioriterar inkommande behov, vilket ger utrymme att arbeta fokuserat. Här får du stort utrymme att påverka, fatta beslut och driva arbetet framåt, från idé och arkitektur till implementering, driftsättning och långsiktig förvaltning.</p><p><strong>Om rollen</strong></p><p>Du vidareutvecklar vår lakehouse-plattform genom att ansluta nya källsystem och förvalta och förbättra det som redan finns. Rollen är bred och rör allt från inhämtning och transformation till infrastruktur och deployflöden, där Infrastructure as Code väger tyngre än i en typisk Data Engineer-roll.</p><p>Vi arbetar i Databricks och dbt på Azure, med infrastrukturen som kod i OpenTofu och Spacelift och deployflöden i GitHub Actions.</p><p><strong>Dina huvudsakliga ansvarsområden</strong></p><ul><li>Ansluta nya källsystem och bygga robusta dataflöden i Databricks och dbt, inklusive transformation, tester och dokumentation.</li><li>Bygga och underhålla våra dataleveranser till omgivande system.</li><li>Driva och vidareutveckla våra IaC-lösningar samt automatisera CI/CD-flöden och infrastruktur.</li><li>Säkra datakvalitet, observability, spårbarhet och säkerhet i nära samarbete med teamet.</li><li>Bidra i den dimensionella modelleringen.</li><li>Samarbeta med analytiker, produktägare och verksamheten för att reda ut vad som faktiskt beh</li><li>övs innan lösningen byggs.</li><li>Delta i tekniska vägval och vara med och forma plattformens utveckling framåt.</li></ul><p><strong>Vem är du?</strong></p><p>Vi söker dig som har några års erfarenhet som Data Engineer, Analytics Engineer, plattformsingenjör eller backendutvecklare med starkt datafokus.</p><p>Du trivs med att arbeta självständigt i ett mindre team och har en stark känsla av ägarskap. Du behöver inte ha alla svar från början, men du är van vid att undersöka alternativ, fatta välgrundade beslut och driva arbetet framåt utan detaljerad styrning.</p><p><strong>Din profil</strong></p><ul><li>Goda kunskaper i SQL och Python, med vana vid moduler, beroendehantering och tester.</li><li>Erfarenhet av Databricks eller annan lakehouse-plattform</li><li>Erfarenhet av Infrastructure as Code (exempelvis Terraform eller OpenTofu) samt av CI/CD och versionshantering som ordinarie arbetssätt.</li><li>God blick för datakvalitet, driftsäkerhet och modern observability.</li><li>Svenska och engelska i tal och skrift.</li></ul><p><strong>Det är meriterande om du har erfarenhet av</strong></p><ul><li>Spacelift eller annan IaC-orkestrering.</li><li>Declarative Automation Bundles (tidigare Databricks Asset Bundles).</li><li>Dbt eller motsvarande transformationsverktyg</li><li>Integrationer mot ERP- eller HR-system.</li><li>Lakehouse-arkitektur, data governance och Unity Catalog.</li><li>Power BI och semantisk modellering.</li></ul><p>Vi lägger stor vikt vid din nyfikenhet, din problemlösningsförmåga och din vilja att utvecklas tillsammans med oss.</p><p><strong>Om AcadeMedia</strong></p><p>AcadeMedia är Europas största utbildningsföretag med verksamhet i stora delar av Europa. Genom våra förskolor, grundskolor, gymnasier och vuxenutbildningar bidrar vi varje dag till att utveckla utbildning för barn, unga och vuxna. Data &amp; Analytics-teamet arbetar centralt mot samtliga dessa verksamheter.</p><p><strong>Övrig information</strong></p><p><strong>Tjänstens omfattning och placering</strong>Tjänsten är en tillsvidareanställn ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5565688479',
#     'name': 'AcadeMedia Support AB',
#     'workplace': 'AcadeMedia Support'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://academedia.se/om-oss/jobba-hos-oss/lediga-jobb/?jobid=318459&ref=platsbankenv2',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': '11137',
#     'city': 'Stockholm',
#     'coordinates': [18.06149880255592, 59.33670594541106]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': None,
#      'postcode': '11137',
#      'city': 'Stockholm',
#      'coordinates': [18.06149880255592, 59.33670594541106]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [{'weight': 5,
#       'concept_id': 'zSLA_vw2_FXN',
#       'label': 'Svenska',
#       'legacy_ams_taxonomy_id': '502'},
#      {'weight': 5,
#       'concept_id': 'NVxJ_hLg_TYS',
#       'label': 'Engelska',
#       'legacy_ams_taxonomy_id': '283'}],
#     'work_experiences': [{'weight': 5,
#       'concept_id': '9U5Y_9Ji_uJq',
#       'label': 'Dataingenjör',
#       'legacy_ams_taxonomy_id': '7338'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-15T16:31:31',
#    'last_publication_date': '2026-10-19T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1789482691256},
#   {'relevance': 1.0,
#    'id': '31457329',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31457329',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5560015835/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-10-04T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Vill du göra konkret skillnad med data? Hos oss är analytics redan starkt och vår nya AI‑satsning behöver din kompetens. Du får en nyckelroll i att göra data tillgänglig, tillförlitlig och användbar, både för människor och för agentisk AI.\n\nDen hållbara omställningen börjar med oss\n\nVi står inför vår största utmaning hittills – att se till att Sverige och Europa har det som krävs för att ställa om. Så att vi kan leva det liv vi vill, nu och imorgon. På samma sätt som vi vill förbättra framtiden, vill vi utveckla alla som är med oss på resan, personligt och professionellt. Vill du vara med och lägga grunden för det liv vi lever och som bygger världen omkring oss?\n\nDin roll\n\nSom Data Engineer i sektionen Data, Analytics & AI får du en central roll i vår satsning på att göra data tillgänglig och användbar. Du designar och bygger datapipelines som förädlar rådata till säkra, tillförlitliga och skalbara datamodeller för både människor och AI-agenter. I sektionen samlas kompetens inom Data Engineering, Analytics Engineering samt Data Science och AI/Machine Learning, vilket ger stora möjligheter till samarbete och kunskapsutbyte. Dina lösningar blir grunden för analys, välgrundade beslut och agentiska AI-lösningar.\n\nDu kommer bland annat att:\n\nUtveckla och förvalta datapipelines för inhämtning, transformation och lagring av data\nBygga och vidareutveckla datamodeller som gör data tillgänglig, användbar och tillförlitlig\nSäkerställa datakvalitet, prestanda och stabilitet i dataplattformen\nBidra till utvecklingen av dataprodukter och AI-drivna arbetssätt\nUtforska och tillämpa nya teknologier inom data, molnplattformar och AI\n\n\nDu är med och vidareutvecklar vår moderna dataplattform och arbetar med data från många olika verksamhetsområden, allt från produktion och logistik till ekonomi och HR. Vi anpassar ständigt vår arbetsmodell för att hålla jämna steg med det snabba tempot i omvärlden.\n\nDet här har du med dig\n\nDu är en strukturerad och ansvarstagande person som trivs med att skapa ordning i komplexa miljöer. Du är nyfiken på ny teknik, AI och nya arbetssätt, och motiveras av att utveckla lösningar som gör data tillgänglig och användbar. För att lyckas i rollen samarbetar du gärna med andra, har ett problemlösande förhållningssätt och kan förstå och omsätta verksamhetens behov till tekniska lösningar.\n\nVidare har du:\n\nUtbildning inom data/IT eller motsvarande erfarenhet\nErfarenhet av att bygga och förvalta datapipelines och ETL/ELT‑flöden\nGoda kunskaper i SQL, Python och datamodellering\nKänsla för datakvalitet och för att göra data tillförlitlig och användbar för olika målgrupper\nGoda kunskaper i svenska och engelska, både i tal och skrift\nB-körkort\n\n\nDet är meriterande om du har erfarenhet av något av följande:\n\nPraktisk erfarenhet av AI‑assisterad utveckling och intresse för agentisk AI\nErfarenhet av BI‑verktyg, t.ex. Power BI, eller av semantiska modeller\nErfarenhet av molnplattformar, moderna dataarkitekturer och verktyg för orkestrering\nErfarenhet av att arbeta i en säker arkitektur samt kunskap om datahantering och informationssäkerhet\n\n\nVarmt välkommen med din ansökan!\u200b\n\nVi strävar efter en rättvis och objektiv rekryteringsprocess. Därför ber vi vanligtvis inte om personliga brev. I stället ber vi dig att svara på frågor relaterat till den specifika tjänsten du söker. Dina svar hjälper oss att förstå din kompetens och erfarenhet, så ta dig tid att svara så tydligt och utförligt som möjligt.\n\nAnsökningar behandlas löpande, så vänta inte med din ansökan.\n\nStart:\u202fEnligt överenskommelse.\n\nPlats: Kiruna Gällivare, eller Luleå\n\nOmfattning: Heltid, dagtid\n\nKontakt: För mer information om tjänsten är du välkommen att kontakta rekryterande chef Daniel Nordvall, daniel.nordvall@lkab.com, 072 707 6701\n\nFackliga kontakter Kiruna/ Svappavaara:\n\nSakari Alanko, Unionen, 0980-725 08\nLedarna Norra, ledarna.norra@lkab.com\nPeter Johansson, Akademike ...
#     'text_formatted': '<p>Vill du göra konkret skillnad med data? Hos oss är analytics redan starkt och vår nya AI‑satsning behöver din kompetens. Du får en nyckelroll i att göra data tillgänglig, tillförlitlig och användbar, både för människor och för agentisk AI.</p>\n<p>Den hållbara omställningen börjar med oss</p>\n<p>Vi står inför vår största utmaning hittills – att se till att Sverige och Europa har det som krävs för att ställa om. Så att vi kan leva det liv vi vill, nu och imorgon. På samma sätt som vi vill förbättra framtiden, vill vi utveckla alla som är med oss på resan, personligt och professionellt. Vill du vara med och lägga grunden för det liv vi lever och som bygger världen omkring oss?</p>\n<p>Din roll</p>\n<p>Som Data Engineer i sektionen Data, Analytics & AI får du en central roll i vår satsning på att göra data tillgänglig och användbar. Du designar och bygger datapipelines som förädlar rådata till säkra, tillförlitliga och skalbara datamodeller för både människor och AI-agenter. I sektionen samlas kompetens inom Data Engineering, Analytics Engineering samt Data Science och AI/Machine Learning, vilket ger stora möjligheter till samarbete och kunskapsutbyte. Dina lösningar blir grunden för analys, välgrundade beslut och agentiska AI-lösningar.</p>\n<p>Du kommer bland annat att:</p>\n<ul><li>Utveckla och förvalta datapipelines för inhämtning, transformation och lagring av data</li><li>Bygga och vidareutveckla datamodeller som gör data tillgänglig, användbar och tillförlitlig</li><li>Säkerställa datakvalitet, prestanda och stabilitet i dataplattformen</li><li>Bidra till utvecklingen av dataprodukter och AI-drivna arbetssätt</li><li>Utforska och tillämpa nya teknologier inom data, molnplattformar och AI</li></ul>\n<p>Du är med och vidareutvecklar vår moderna dataplattform och arbetar med data från många olika verksamhetsområden, allt från produktion och logistik till ekonomi och HR. Vi anpassar ständigt vår arbetsmodell för att hålla jämna steg med det snabba tempot i omvärlden.</p>\n<p>Det här har du med dig</p>\n<p>Du är en strukturerad och ansvarstagande person som trivs med att skapa ordning i komplexa miljöer. Du är nyfiken på ny teknik, AI och nya arbetssätt, och motiveras av att utveckla lösningar som gör data tillgänglig och användbar. För att lyckas i rollen samarbetar du gärna med andra, har ett problemlösande förhållningssätt och kan förstå och omsätta verksamhetens behov till tekniska lösningar.</p>\n<p>Vidare har du:</p>\n<ul><li>Utbildning inom data/IT eller motsvarande erfarenhet</li><li>Erfarenhet av att bygga och förvalta datapipelines och ETL/ELT‑flöden</li><li>Goda kunskaper i SQL, Python och datamodellering</li><li>Känsla för datakvalitet och för att göra data tillförlitlig och användbar för olika målgrupper</li><li>Goda kunskaper i svenska och engelska, både i tal och skrift</li><li>B-körkort</li></ul>\n<p>Det är meriterande om du har erfarenhet av något av följande:</p>\n<ul><li>Praktisk erfarenhet av AI‑assisterad utveckling och intresse för agentisk AI</li><li>Erfarenhet av BI‑verktyg, t.ex. Power BI, eller av semantiska modeller</li><li>Erfarenhet av molnplattformar, moderna dataarkitekturer och verktyg för orkestrering</li><li>Erfarenhet av att arbeta i en säker arkitektur samt kunskap om datahantering och informationssäkerhet</li></ul>\n<p><strong>Varmt välkommen med din ansökan!\u200b</strong></p>\n<p>Vi strävar efter en rättvis och objektiv rekryteringsprocess. Därför ber vi vanligtvis inte om personliga brev. I stället ber vi dig att svara på frågor relaterat till den specifika tjänsten du söker. Dina svar hjälper oss att förstå din kompetens och erfarenhet, så ta dig tid att svara så tydligt och utförligt som möjligt.</p>\n<p>Ansökningar behandlas löpande, så vänta inte med din ansökan.</p>\n<p>Start:\u202fEnligt överenskommelse.</p>\n<p>Plats: Kiruna Gällivare, eller Luleå</p>\n<p>Omfattning: Heltid, dagtid</p>\n<p>Kontakt: För mer information om tjänsten är du välkommen att konta ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5560015835',
#     'name': 'Luossavaara-Kiirunavaara Aktiebolag',
#     'workplace': 'Luleå'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://easyapply.jobs/r/4Jygcs428dxol4WCIOL',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': None,
#    'occupation': {'concept_id': 'rz2m_96d_vyF',
#     'label': 'Databasutvecklare',
#     'legacy_ams_taxonomy_id': '2423'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Gällivare',
#     'municipality_code': '2523',
#     'municipality_concept_id': '6R2u_zkb_uoS',
#     'region': 'Norrbottens län',
#     'region_code': '25',
#     'region_concept_id': '9hXe_F4g_eTG',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': '97775',
#     'city': 'Luleå',
#     'coordinates': [20.65936, 67.1379]},
#    'workplace_addresses': [{'municipality': 'Gällivare',
#      'municipality_code': '2523',
#      'municipality_concept_id': '6R2u_zkb_uoS',
#      'region': 'Norrbottens län',
#      'region_code': '25',
#      'region_concept_id': '9hXe_F4g_eTG',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': None,
#      'postcode': '97775',
#      'city': 'Luleå',
#      'coordinates': [20.65936, 67.1379]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-09T14:42:36',
#    'last_publication_date': '2026-10-04T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1788957756854},
#   {'relevance': 1.0,
#    'id': '30979729',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30979729',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-10-27T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Om oss På Techrytera AB börjar rekryteringen med dig. Vi är ett bemannings- och rekryteringsföretag med spetskompetens och ett tydligt fokus inom IT och Engineering. Med vår branschkunskap och nära dialog med både kandidater och kunder skapar vi träffsäkra matchningar där rätt kompetens möter rätt behov.\nVi tror att en riktigt bra matchning inte bara handlar om en rollbeskrivning – utan om dina erfarenheter, din potential och vad du faktiskt vill utvecklas inom. Därför utgår vi alltid från individen. Genom att förstå din bakgrund, dina drivkrafter och dina ambitioner kan vi koppla ihop dig med uppdrag och roller hos våra kunder där du får rätt förutsättningar att utvecklas och göra skillnad.\nVårt mål är att bygga långsiktiga och meningsfulla samarbeten – både för dig som kandidat och för våra kunder.\nArbetsbeskrivning Vi söker en erfaren och analytisk Data Engineer som vill arbeta med att förstå och optimera vår kunds datatransaktioner.\n\nSom Data Engineer blir du en nyckelperson i vår kunds team och ansvarar för att analysera, strukturera och förbättra deras interna dataprocesser och kopplingar mellan system. Du kommer att arbeta med stora datamängder, bygga effektiva pipelines och säkerställa datakvalitet för att stödja verksamhetens behov.\n\nVår kunds vision är att ta en ledande position på elmarknaden och bygga stabila, datadrivna lösningar som bidrar till ett hållbart energisystem. Nu behöver de din hjälp för att komma dit.\n\nDina ansvarsområden\n\nAnalysera och förstå datatransaktioner mellan våra system.\n\n\nUtveckla och optimera datamodeller, pipelines och integrationer.\n\n\nArbeta med databaser som MSSQL, Oracle, Snowflake och verktyg som DBT.\n\n\nSäkerställa datakvalitet, prestanda och tillgänglighet.\n\n\nSamarbeta med utvecklare, analytiker och verksamheten för att skapa effektiva datalösningar.\n\n\n\n\n\nNödvändiga färdigheter\n\nDokumenterad erfarenhet av SQL och arbete med relationsdatabaser.\n\n\nErfarenhet av databaser som MSSQL, Oracle, Snowflake.\n\n\nKunskap om ETL-processer och dataintegration.\n\n\nFörståelse för datamodellering och optimering av databaser.\n\n\nErfarenhet av att arbeta med DBT eller liknande verktyg för data transformation.\n\n\nGrundläggande förståelse för dataskydd och säkerhet.\n\n\n\nMeriterande färdigheter\n\nErfarenhet av Python eller andra språk för datahantering.\n\n\nKunskap om molnplattformar (Azure, AWS eller GCP).\n\n\nErfarenhet av dataanalys och visualisering.\n\n\nArbetat med IoT, MQTT och realtidsdata samt förstå konsekvenserna av bearbetning av realtidsdata för analys\n\n\nVana att arbeta i agila team och med DevOps-principer.\n\n\n\nAnsökan När du söker via Techrytera AB söker du inte bara ett jobb – du påbörjar en dialog om din fortsatta karriär. Vi vill lära känna dig, din erfarenhet och dina ambitioner för att kunna matcha dig med rätt möjligheter hos våra kunder.\nLåter det intressant? Skicka in din ansökan eller hör av dig till oss så berättar vi mer. Vi ser fram emot att hitta nästa steg i din karriär tillsammans med dig.',
#     'text_formatted': '<p><strong>Om oss</strong> På Techrytera AB börjar rekryteringen med dig. Vi är ett bemannings- och rekryteringsföretag med spetskompetens och ett tydligt fokus inom IT och Engineering. Med vår branschkunskap och nära dialog med både kandidater och kunder skapar vi träffsäkra matchningar där rätt kompetens möter rätt behov.</p><p>Vi tror att en riktigt bra matchning inte bara handlar om en rollbeskrivning – utan om dina erfarenheter, din potential och vad du faktiskt vill utvecklas inom. Därför utgår vi alltid från individen. Genom att förstå din bakgrund, dina drivkrafter och dina ambitioner kan vi koppla ihop dig med uppdrag och roller hos våra kunder där du får rätt förutsättningar att utvecklas och göra skillnad.</p><p>Vårt mål är att bygga långsiktiga och meningsfulla samarbeten – både för dig som kandidat och för våra kunder.</p><p><strong>Arbetsbeskrivning</strong> Vi söker en erfaren och analytisk Data Engineer som vill arbeta med att förstå och optimera vår kunds datatransaktioner.</p><p></p><p>Som Data Engineer blir du en nyckelperson i vår kunds team och ansvarar för att analysera, strukturera och förbättra deras interna dataprocesser och kopplingar mellan system. Du kommer att arbeta med stora datamängder, bygga effektiva pipelines och säkerställa datakvalitet för att stödja verksamhetens behov.</p><p></p><p>Vår kunds vision är att ta en ledande position på elmarknaden och bygga stabila, datadrivna lösningar som bidrar till ett hållbart energisystem. Nu behöver de din hjälp för att komma dit.</p><p></p><p><strong>Dina ansvarsområden</strong></p><ul><li><p>Analysera och förstå datatransaktioner mellan våra system.</p></li><li><p>Utveckla och optimera datamodeller, pipelines och integrationer.</p></li><li><p>Arbeta med databaser som MSSQL, Oracle, Snowflake och verktyg som DBT.</p></li><li><p>Säkerställa datakvalitet, prestanda och tillgänglighet.</p></li><li><p>Samarbeta med utvecklare, analytiker och verksamheten för att skapa effektiva datalösningar.</p></li><li><p></p></li></ul><p><strong>Nödvändiga färdigheter</strong></p><ul><li><p>Dokumenterad erfarenhet av SQL och arbete med relationsdatabaser.</p></li><li><p>Erfarenhet av databaser som MSSQL, Oracle, Snowflake.</p></li><li><p>Kunskap om ETL-processer och dataintegration.</p></li><li><p>Förståelse för datamodellering och optimering av databaser.</p></li><li><p>Erfarenhet av att arbeta med DBT eller liknande verktyg för data transformation.</p></li><li><p>Grundläggande förståelse för dataskydd och säkerhet.</p></li></ul><p></p><p><strong>Meriterande färdigheter</strong></p><ul><li><p>Erfarenhet av Python eller andra språk för datahantering.</p></li><li><p>Kunskap om molnplattformar (Azure, AWS eller GCP).</p></li><li><p>Erfarenhet av dataanalys och visualisering.</p></li><li><p>Arbetat med IoT, MQTT och realtidsdata samt förstå konsekvenserna av bearbetning av realtidsdata för analys</p></li><li><p>Vana att arbeta i agila team och med DevOps-principer.</p></li></ul><p></p><p><strong>Ansökan </strong>När du söker via Techrytera AB söker du inte bara ett jobb – du påbörjar en dialog om din fortsatta karriär. Vi vill lära känna dig, din erfarenhet och dina ambitioner för att kunna matcha dig med rätt möjligheter hos våra kunder.</p><p>Låter det intressant? Skicka in din ansökan eller hör av dig till oss så berättar vi mer. Vi ser fram emot att hitta nästa steg i din karriär tillsammans med dig.</p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.techrytera.se',
#     'organization_number': '5595683623',
#     'name': 'Techrytera AB',
#     'workplace': 'Techrytera AB'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7664325-1975879',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.techrytera.se/jobs/7664325-data-engineer/applications/new?promotion=1975879-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Jönköping',
#     'municipality_code': '0680',
#     'municipality_concept_id': 'KURg_KJF_Lwc',
#     'region': 'Jönköpings län',
#     'region_code': '06',
#     'region_concept_id': 'MtbE_xWT_eMi',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Jönköping Centralstation',
#     'postcode': '55311',
#     'city': 'Jonkoping',
#     'coordinates': [14.153488293662027, 57.79699409575457]},
#    'workplace_addresses': [{'municipality': 'Jönköping',
#      'municipality_code': '0680',
#      'municipality_concept_id': 'KURg_KJF_Lwc',
#      'region': 'Jönköpings län',
#      'region_code': '06',
#      'region_concept_id': 'MtbE_xWT_eMi',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Jönköping Centralstation',
#      'postcode': '55311',
#      'city': 'Jonkoping',
#      'coordinates': [14.153488293662027, 57.79699409575457]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-04-30T11:53:20',
#    'last_publication_date': '2026-10-27T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1777573624056},
#   {'relevance': 0.9860408968221264,
#    'id': '31472390',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31472390',
#    'logo_url': None,
#    'headline': 'Data engineer',
#    'application_deadline': '2026-09-17T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Senior Data Engineer – Stockholm/Solna | 80% | Consultant\nWe are looking for a Senior Data Engineer / BI Consultant for a long-term consulting assignment in Stockholm/Solna.\nStart: 12 October 2026\nDuration: Until 12 June 2027, with possibility of extension\nLocation: Solna/Stockholm, hybrid – normally 3 days/week on site\nExtent: 80%\nRequired:\n• 2+ years of R and Python programming experience within the last 5 years\n• Experience designing data visualization solutions within the last 2 years\n• 2+ years of ETL and SQL experience within the last 6 years\n• 3+ years of SAS experience within the last 6 years\n• 3+ years of Power BI experience within the last 6 years\n• 3+ years of experience working with large amounts of data\n• 3+ years of experience working in organizations with 500+ employees\n• Good Swedish, both spoken and written\n• Competency Level 4 / senior-level experience\nKey skills: R, Python, SAS, Power BI, SQL, ETL, Data Visualization, Data Engineering and BI.\nInterested? Please send your updated CV to recruiter@i-raysolutions.com.',
#     'text_formatted': '<p><strong>Senior Data Engineer – Stockholm/Solna | 80% | Consultant</strong></p><p>We are looking for a Senior Data Engineer / BI Consultant for a long-term consulting assignment in Stockholm/Solna.</p><p><strong>Start:</strong> 12 October 2026</p><p><strong>Duration:</strong> Until 12 June 2027, with possibility of extension</p><p><strong>Location:</strong> Solna/Stockholm, hybrid – normally 3 days/week on site</p><p><strong>Extent:</strong> 80%</p><p><strong>Required:</strong></p><p>• 2+ years of R and Python programming experience within the last 5 years</p><p>• Experience designing data visualization solutions within the last 2 years</p><p>• 2+ years of ETL and SQL experience within the last 6 years</p><p>• 3+ years of SAS experience within the last 6 years</p><p>• 3+ years of Power BI experience within the last 6 years</p><p>• 3+ years of experience working with large amounts of data</p><p>• 3+ years of experience working in organizations with 500+ employees</p><p>• Good Swedish, both spoken and written</p><p>• Competency Level 4 / senior-level experience</p><p><strong>Key skills:</strong> R, Python, SAS, Power BI, SQL, ETL, Data Visualization, Data Engineering and BI.</p><p>Interested? Please send your updated CV to recruiter@i-raysolutions.com.</p><p><br></p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'sTu5_NBQ_udq',
#     'label': 'Tidsbegränsad anställning',
#     'legacy_ams_taxonomy_id': None},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'gJRb_akA_95y',
#     'label': '6 månader – upp till 12 månader',
#     'legacy_ams_taxonomy_id': '0'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5594173600',
#     'name': 'I-Ray IT Solutions AB',
#     'workplace': 'I-ray IT solutions AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': 'recruiter@i-raysolutions.com',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'vpAN_viS_cFV',
#     'label': 'Databasanalytiker',
#     'legacy_ams_taxonomy_id': '7755'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': None,
#     'municipality_code': None,
#     'municipality_concept_id': None,
#     'region': None,
#     'region_code': None,
#     'region_concept_id': None,
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'workplace_addresses': [{'municipality': None,
#      'municipality_code': None,
#      'municipality_concept_id': None,
#      'region': None,
#      'region_code': None,
#      'region_concept_id': None,
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': None,
#      'postcode': None,
#      'city': None,
#      'coordinates': [None, None]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'vpAN_viS_cFV',
#       'label': 'Databasanalytiker',
#       'legacy_ams_taxonomy_id': '7755'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-14T10:47:10',
#    'last_publication_date': '2026-09-17T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1789375630755},
#   {'relevance': 0.9860408968221264,
#    'id': '31444481',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31444481',
#    'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5560743089/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-09-17T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': "Company description:\nWho are we?Volvo Cars is a company on a mission; to bring traditional car manufacturing into a connected, sustainable and smart future.Since 1927, we have been a brand known for our commitment to safety, creating innovative cars that make life less complicated for our consumers. In 2010, we decided to transform our business, resulting in a totally new generation of cars and technologies, as well as steady growth and record sales. Today, we’re expanding our global footprint in Europe, China and the US, and we’re on the lookout for new talent. We are constantly pushing our own skills and abilities to drive change in the automobile industry like never before. We are looking for innovative, committed people to join us in this endeavour and create safe, sustainable and connected cars. We believe in the power of people and will challenge and support you to reach your full potential. Join us and be part of Volvo Cars’ journey into the future.\nJob description:   Let's introduce ourselves \nWe are looking for a Data Engineer to join Materials Engineering Centre (MEC) at Volvo Cars Headquarters in Gothenburg. Do you want to grow your career together with dedicated colleagues working on future mobility solutions?At MEC, we support engineering, design, and procurement teams in selecting the right materials for the right application at the right time. As electrification accelerates, the role of structured, high-quality material data becomes increasingly critical.In this role, you will be a key contributor in building and developing our material data capabilities, enabling efficient data flows and supporting engineering decisions across the organization.\n What you'll do \nYou will be part of a team working at the intersection of materials engineering and data, focusing on how material data is created, structured, and used across the organization.\n Your main responsibilities include:\n  Develop and maintain material data flows between systems and tools\n Drive and support material card creation, combining material data, modelling, and validation\n Work with modelling, DFT and FE calculations to describe and validate material behaviour\n Ensure data quality, traceability, and structure across material datasets\n Collaborate with engineers, analysts, and laboratory teams to integrate experimental data into usable formats\n Support and drive digitalization and automation of engineering workflows\n Develop and maintain scripts and tools for managing engineering data\n Contribute to continuous improvement of systems, methods, and data structures\n Support data visualization and reporting across the department\n  \nSupport lab activities with knowledge in mechanical testing with DIC technique.\xa0\n   Profile description:  What you'll bring \nWe believe you are a curious and collaborative person who enjoys working in a cross-functional environment. You are motivated by connecting physical material knowledge with digital solutions and see the value of structured, high-quality data.Required qualifications:\n  PhD/MSc in Materials Science, Engineering Physics, Data Engineering, or a related field\n Strong interest and understanding of DFT and FE modelling and material behaviour\n Strong Material knowledge\n  \nMerits:\n  Practical lab experience and understanding of material testing and validation and workflows\n Knowledge of characterization techniques such as CLTE, DMA, FTIR, SEM and mechanical testing (including imaging techniques)\n Experience working with experimental data and transferring it into simulation or modelling environments\n  \xa0 \nTechnical skills:\n We are looking for a mix of engineering and digital capabilities:\n  Python – strong understanding, ability to develop and maintain scripts in production environments\n Power Automate – solid experience in designing both simple and more advanced automation flows\n Power BI – strong skills in building reports, managing datasets, and su ...
# ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5565595450',
#     'name': 'Academic Work Sweden AB',
#     'workplace': 'Academic Work Sweden AB'},
#    'application_details': {'information': None,
#     'reference': 'GUMSZN',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.academicwork.se/lediga-jobb/p/platsbanken/GUMSZN',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Malmö',
#     'municipality_code': '1280',
#     'municipality_concept_id': 'oYPt_yRA_Smm',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Östergatan 18',
#     'postcode': '21125',
#     'city': 'Malmö',
#     'coordinates': [13.005912037624, 55.6075939489136]},
#    'workplace_addresses': [{'municipality': 'Malmö',
#      'municipality_code': '1280',
#      'municipality_concept_id': 'oYPt_yRA_Smm',
#      'region': 'Skåne län',
#      'region_code': '12',
#      'region_concept_id': 'CaRE_1nn_cSU',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Östergatan 18',
#      'postcode': '21125',
#      'city': 'Malmö',
#      'coordinates': [13.005912037624, 55.6075939489136]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-09-09T13:52:44',
#    'last_publication_date': '2027-03-08T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1788954764422},
#   {'relevance': 0.25183424011667577,
#    'id': '30900557',
#    'external_id': None,
#    'original_id': None,
#    'label': [],
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30900557',
#    'logo_url': None,
#    'headline': 'Senior Data & AI Platform Engineer till Axfood IT',
#    'application_deadline': '2026-10-11T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Välkommen till Axfood IT, en av matbranschens största IT-avdelningar med nästan 400 teknikspecialister. Det är vi som ser till att Axfood, och alla våra kedjor, kan ligga i framkant vad gäller digital utveckling. Tillsammans utvecklar vi några av Sveriges mest avancerade digitala lösningar inom e-handel, logistik, automation, planering och AI.\n Det här är rollen för dig som går igång på att bygga verktyg, plattformar och automatiserade flöden som andra utvecklare älskar att använda. För dig som vill skapa stabila, säkra och eleganta system som gör det enkelt för hela organisationen att jobba datadrivet - och där du får vara med och definiera standarden för hur data och AI utvecklas, driftsätts och förvaltas.\n Ditt nya team\nI rollen tillhör du vår avdelning Data & AI Center och teamet som arbetar med data- & AI-plattformar. Du kommer att arbeta nära flera andra kompetenta Platform Engineers, Arkitekter och Data Engineers och nära nya teamet AI Center, som är en del av Axfoods fortsatta satsning på egenutvecklad AI.\nVåra Data- & AI-plattformar är avgörande för att Axfood ska fatta välgrundade beslut och driva affärsframgångar och vi söker nu dig som vill vara med att utveckla våra plattformar för att möta framtida behov av data & AI. Tillsammans utvecklar vi dessa plattformar som driver allt från sortimentsoptimering till ruttplanering och integrerad realtidsanalys. \nOm rollen\nSom Data & AI Platform Engineer har du en central roll i att designa, utveckla och vidareutveckla Axfoods data- och AI-plattformar i AWS. Du bygger moderna, skalbara och säkra plattformar som stödjer affärskritiska system och möjliggör Axfoods fortsatta satsning inom Data och AI, med fokus på automation, serverless-arkitektur och kostnadseffektivitet.\nDu arbetar med att utveckla och optimera data lakehouse-förmågor, skapa strukturer för hur data publiceras och konsumeras, samt säkerställa stabil drift, prestanda och tillgänglighet genom kontinuerlig förbättring och förvaltning. Rollen innebär ett nära samarbete med arkitekter, Data/ML Engineers och andra utvecklare för att bygga robusta och långsiktiga plattformslösningar, där hög grad av automatisering och self-service är en central del av arbetssättet.\n\nTech Stack:\n· Python, SQL\n· Cloud Plattform: AWS\n· Compute: Fully Serverless (Lambda/ECS Fargate & DuckDB och Glue & Spark, SQS)\n· Storage: Data Lakehouse (Apache Iceberg / S3Tables), DynamoDB\n· Orkestreringsverktyg: Airflow\n· Accessverktyg: AD, IAM, Lakeformation\n· DevOps: Docker, AWS CDK & Bitbucket pipelines\n· Engineering Practices: IaC, CI/CD, linting, testning, PR Reviews, interna demos\n\nStämmer detta in på dig?\nDu drivs av att bygga stabila och skalbara plattformar som andra team kan lita på och utveckla vidare på. Du har en god förståelse för moderna moln- och dataplattformar samt erfarenhet av automation, driftkvalitet och Infrastructure as Code.\nDu har förmåga att designa hållbara system och strukturer, och erfarenhet av att arbeta med livscykelhantering och versionering av data, kod och modeller. Du trivs i en miljö där du får bidra till struktur, förbättring och långsiktiga lösningar.\nSom person är du strukturerad, nyfiken och lösningsorienterad, med hög kvalitetsmedvetenhet och god samarbetsförmåga.\n\nVarför du kommer att trivas här\nDu får vara med och bygga och forma Axfoods data- och AI-plattformar och bidra till en strategisk satsning med stort affärsvärde. Här finns ett stort tekniskt mandat att påverka plattformens riktning, standarder och arbetssätt.\nVi skriver kod som dokumenteras, testas, granskas och ägs av teamet. Vi värdesätter läsbarhet, stabilitet och hög utvecklarvänlighet över snabbhet.\nDu arbetar tillsammans med kompetenta kollegor i en miljö där modern engineering, kvalitet och långsiktighet står i fokus. Teamet präglas av ett öppet klimat, hög tillit och ett gemensamt engagemang för att bygga robusta lösningar som gör verklig skillnad.\n\nAnsökningsprocessen\nVi vill att d ...
#     'text_formatted': '<p></p><p>Välkommen till Axfood IT, en av matbranschens största IT-avdelningar med nästan 400 teknikspecialister. Det är vi som ser till att Axfood, och alla våra kedjor, kan ligga i framkant vad gäller digital utveckling. Tillsammans utvecklar vi några av Sveriges mest avancerade digitala lösningar inom e-handel, logistik, automation, planering och AI.</p><p> Det här är rollen för dig som går igång på att bygga verktyg, plattformar och automatiserade flöden som andra utvecklare älskar att använda. För dig som vill skapa stabila, säkra och eleganta system som gör det enkelt för hela organisationen att jobba datadrivet - och där du får vara med och definiera standarden för hur data och AI utvecklas, driftsätts och förvaltas.</p><p><strong> Ditt nya team</strong></p><p>I rollen tillhör du vår avdelning Data &amp; AI Center och teamet som arbetar med data- &amp; AI-plattformar. Du kommer att arbeta nära flera andra kompetenta Platform Engineers, Arkitekter och Data Engineers och nära nya teamet AI Center, som är en del av Axfoods fortsatta satsning på egenutvecklad AI.</p><p>Våra Data- &amp; AI-plattformar är avgörande för att Axfood ska fatta välgrundade beslut och driva affärsframgångar och vi söker nu dig som vill vara med att utveckla våra plattformar för att möta framtida behov av data &amp; AI. Tillsammans utvecklar vi dessa plattformar som driver allt från sortimentsoptimering till ruttplanering och integrerad realtidsanalys. </p><p><strong>Om rollen</strong></p><p>Som Data &amp; AI Platform Engineer har du en central roll i att designa, utveckla och vidareutveckla Axfoods data- och AI-plattformar i AWS. Du bygger moderna, skalbara och säkra plattformar som stödjer affärskritiska system och möjliggör Axfoods fortsatta satsning inom Data och AI, med fokus på automation, serverless-arkitektur och kostnadseffektivitet.</p><p>Du arbetar med att utveckla och optimera data lakehouse-förmågor, skapa strukturer för hur data publiceras och konsumeras, samt säkerställa stabil drift, prestanda och tillgänglighet genom kontinuerlig förbättring och förvaltning. Rollen innebär ett nära samarbete med arkitekter, Data/ML Engineers och andra utvecklare för att bygga robusta och långsiktiga plattformslösningar, där hög grad av automatisering och self-service är en central del av arbetssättet.</p><p></p><p><strong>Tech Stack:</strong></p><p>· Python, SQL</p><p>· Cloud Plattform: AWS</p><p>· Compute: Fully Serverless (Lambda/ECS Fargate &amp; DuckDB och Glue &amp; Spark, SQS)</p><p>· Storage: Data Lakehouse (Apache Iceberg / S3Tables), DynamoDB</p><p>· Orkestreringsverktyg: Airflow</p><p>· Accessverktyg: AD, IAM, Lakeformation</p><p>· DevOps: Docker, AWS CDK &amp; Bitbucket pipelines</p><p>· Engineering Practices: IaC, CI/CD, linting, testning, PR Reviews, interna demos</p><p></p><p><strong>Stämmer detta in på dig?</strong></p><p>Du drivs av att bygga stabila och skalbara plattformar som andra team kan lita på och utveckla vidare på. Du har en god förståelse för moderna moln- och dataplattformar samt erfarenhet av automation, driftkvalitet och Infrastructure as Code.</p><p>Du har förmåga att designa hållbara system och strukturer, och erfarenhet av att arbeta med livscykelhantering och versionering av data, kod och modeller. Du trivs i en miljö där du får bidra till struktur, förbättring och långsiktiga lösningar.</p><p>Som person är du strukturerad, nyfiken och lösningsorienterad, med hög kvalitetsmedvetenhet och god samarbetsförmåga.</p><p></p><p><strong>Varför du kommer att trivas här</strong></p><p>Du får vara med och bygga och forma Axfoods data- och AI-plattformar och bidra till en strategisk satsning med stort affärsvärde. Här finns ett stort tekniskt mandat att påverka plattformens riktning, standarder och arbetssätt.</p><p>Vi skriver kod som dokumenteras, testas, granskas och ägs av teamet. Vi värdesätter läsbarhet, stabilitet och hög utvecklarvänlighet över snabbhet.</p><p>Du arbetar tillsammans med kompetenta ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://jobb.ants.se',
#     'organization_number': '5566536230',
#     'name': 'Ants Akademiskt Nätverk av Tekniska Studenter AB',
#     'workplace': 'Ants'},
#    'application_details': {'information': None,
#     'reference': 'teamtailor-7365275-1944587',
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobb.ants.se/jobs/7365275-senior-data-ai-platform-engineer-till-axfood-it/applications/new?promotion=1944587-arbetsformedlingen',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'fg7B_yov_smw',
#     'label': 'Systemutvecklare/Programmerare',
#     'legacy_ams_taxonomy_id': '2419'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_model': {'concept_id': 'ZxwM_gtz_n61',
#     'label': 'Arbete på plats'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Virkesvägen 2',
#     'postcode': '12030',
#     'city': 'Stockholm',
#     'coordinates': [18.090788682065, 59.3013378370419]},
#    'workplace_addresses': [{'municipality': 'Stockholm',
#      'municipality_code': '0180',
#      'municipality_concept_id': 'AvNB_uwa_6n6',
#      'region': 'Stockholms län',
#      'region_code': '01',
#      'region_concept_id': 'CifL_Rzy_Mku',
#      'country': 'Sverige',
#      'country_code': '199',
#      'country_concept_id': 'i46j_HmG_v64',
#      'street_address': 'Virkesvägen 2',
#      'postcode': '12030',
#      'city': 'Stockholm',
#      'coordinates': [18.090788682065, 59.3013378370419]}],
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2026-04-14T10:18:29',
#    'last_publication_date': '2026-10-11T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_JOBPOSTING',
#    'timestamp': 1779718241182}]}

# %%
json_response["hits"][0]
# Out:
# {'relevance': 1.0,
#  'id': '31481035',
#  'external_id': None,
#  'original_id': None,
#  'label': [],
#  'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/31481035',
#  'logo_url': 'https://arbetsformedlingen.se/rest/employer-logo-api/api/v1/organisation/5565688479/logotyper/logo.png',
#  'headline': 'Data Engineer',
#  'application_deadline': '2026-10-19T23:59:59',
#  'number_of_vacancies': 1,
#  'description': {'text': 'Vill du vara med och forma hur data används i Europas största utbildningsföretag?\nVi söker en Data Engineer som vill ta ansvar för både dataflödena och infrastrukturen de körs på. Hos oss får du vidareutveckla en modern dataplattform som används för analys, rapportering och verksamhetsutveckling inom hela AcadeMedia, och äga den automation som håller den i gång.\nDu blir en del av vårt centrala Data & Analytics-team. Vi är ett mindre team med stort ansvar och nära samarbete mellan teknik och verksamhet. Vi arbetar agilt i sprintar med en produktägare som prioriterar inkommande behov, vilket ger utrymme att arbeta fokuserat. Här får du stort utrymme att påverka, fatta beslut och driva arbetet framåt, från idé och arkitektur till implementering, driftsättning och långsiktig förvaltning.\nOm rollen\nDu vidareutvecklar vår lakehouse-plattform genom att ansluta nya källsystem och förvalta och förbättra det som redan finns. Rollen är bred och rör allt från inhämtning och transformation till infrastruktur och deployflöden, där Infrastructure as Code väger tyngre än i en typisk Data Engineer-roll.\nVi arbetar i Databricks och dbt på Azure, med infrastrukturen som kod i OpenTofu och Spacelift och deployflöden i GitHub Actions.\nDina huvudsakliga ansvarsområden\nAnsluta nya källsystem och bygga robusta dataflöden i Databricks och dbt, inklusive transformation, tester och dokumentation.\nBygga och underhålla våra dataleveranser till omgivande system.\nDriva och vidareutveckla våra IaC-lösningar samt automatisera CI/CD-flöden och infrastruktur.\nSäkra datakvalitet, observability, spårbarhet och säkerhet i nära samarbete med teamet.\nBidra i den dimensionella modelleringen.\nSamarbeta med analytiker, produktägare och verksamheten för att reda ut vad som faktiskt beh\növs innan lösningen byggs.\nDelta i tekniska vägval och vara med och forma plattformens utveckling framåt.\n\nVem är du?\nVi söker dig som har några års erfarenhet som Data Engineer, Analytics Engineer, plattformsingenjör eller backendutvecklare med starkt datafokus.\nDu trivs med att arbeta självständigt i ett mindre team och har en stark känsla av ägarskap. Du behöver inte ha alla svar från början, men du är van vid att undersöka alternativ, fatta välgrundade beslut och driva arbetet framåt utan detaljerad styrning.\nDin profil\nGoda kunskaper i SQL och Python, med vana vid moduler, beroendehantering och tester.\nErfarenhet av Databricks eller annan lakehouse-plattform\nErfarenhet av Infrastructure as Code (exempelvis Terraform eller OpenTofu) samt av CI/CD och versionshantering som ordinarie arbetssätt.\nGod blick för datakvalitet, driftsäkerhet och modern observability.\nSvenska och engelska i tal och skrift.\n\nDet är meriterande om du har erfarenhet av\nSpacelift eller annan IaC-orkestrering.\nDeclarative Automation Bundles (tidigare Databricks Asset Bundles).\nDbt eller motsvarande transformationsverktyg\nIntegrationer mot ERP- eller HR-system.\nLakehouse-arkitektur, data governance och Unity Catalog.\nPower BI och semantisk modellering.\n\nVi lägger stor vikt vid din nyfikenhet, din problemlösningsförmåga och din vilja att utvecklas tillsammans med oss.\nOm AcadeMedia\nAcadeMedia är Europas största utbildningsföretag med verksamhet i stora delar av Europa. Genom våra förskolor, grundskolor, gymnasier och vuxenutbildningar bidrar vi varje dag till att utveckla utbildning för barn, unga och vuxna. Data & Analytics-teamet arbetar centralt mot samtliga dessa verksamheter.\nÖvrig information\nTjänstens omfattning och placeringTjänsten är en tillsvidareanställning med 6 månaders provanställning. Kontoret ligger på Adolf Fredriks Kyrkogata i Stockholm.\xa0Urval sker löpande och tjänsten kan tillsättas innan sista ansökningsdatum.\nÄr du den vi söker?\xa0Välkommen att skicka in din ansökan innehållande CV\nHar du frågor om tjänsten, varmt välkommen att kontakta rekryterande chef, ylva.drugge@academedia.se\xa0\nVälkommen med din ansökan!\nVi har gjort ...
#   'text_formatted': '<p><strong>Vill du vara med och forma hur data används i Europas största utbildningsföretag?</strong></p><p>Vi söker en Data Engineer som vill ta ansvar för både dataflödena och infrastrukturen de körs på. Hos oss får du vidareutveckla en modern dataplattform som används för analys, rapportering och verksamhetsutveckling inom hela AcadeMedia, och äga den automation som håller den i gång.</p><p>Du blir en del av vårt centrala Data &amp; Analytics-team. Vi är ett mindre team med stort ansvar och nära samarbete mellan teknik och verksamhet. Vi arbetar agilt i sprintar med en produktägare som prioriterar inkommande behov, vilket ger utrymme att arbeta fokuserat. Här får du stort utrymme att påverka, fatta beslut och driva arbetet framåt, från idé och arkitektur till implementering, driftsättning och långsiktig förvaltning.</p><p><strong>Om rollen</strong></p><p>Du vidareutvecklar vår lakehouse-plattform genom att ansluta nya källsystem och förvalta och förbättra det som redan finns. Rollen är bred och rör allt från inhämtning och transformation till infrastruktur och deployflöden, där Infrastructure as Code väger tyngre än i en typisk Data Engineer-roll.</p><p>Vi arbetar i Databricks och dbt på Azure, med infrastrukturen som kod i OpenTofu och Spacelift och deployflöden i GitHub Actions.</p><p><strong>Dina huvudsakliga ansvarsområden</strong></p><ul><li>Ansluta nya källsystem och bygga robusta dataflöden i Databricks och dbt, inklusive transformation, tester och dokumentation.</li><li>Bygga och underhålla våra dataleveranser till omgivande system.</li><li>Driva och vidareutveckla våra IaC-lösningar samt automatisera CI/CD-flöden och infrastruktur.</li><li>Säkra datakvalitet, observability, spårbarhet och säkerhet i nära samarbete med teamet.</li><li>Bidra i den dimensionella modelleringen.</li><li>Samarbeta med analytiker, produktägare och verksamheten för att reda ut vad som faktiskt beh</li><li>övs innan lösningen byggs.</li><li>Delta i tekniska vägval och vara med och forma plattformens utveckling framåt.</li></ul><p><strong>Vem är du?</strong></p><p>Vi söker dig som har några års erfarenhet som Data Engineer, Analytics Engineer, plattformsingenjör eller backendutvecklare med starkt datafokus.</p><p>Du trivs med att arbeta självständigt i ett mindre team och har en stark känsla av ägarskap. Du behöver inte ha alla svar från början, men du är van vid att undersöka alternativ, fatta välgrundade beslut och driva arbetet framåt utan detaljerad styrning.</p><p><strong>Din profil</strong></p><ul><li>Goda kunskaper i SQL och Python, med vana vid moduler, beroendehantering och tester.</li><li>Erfarenhet av Databricks eller annan lakehouse-plattform</li><li>Erfarenhet av Infrastructure as Code (exempelvis Terraform eller OpenTofu) samt av CI/CD och versionshantering som ordinarie arbetssätt.</li><li>God blick för datakvalitet, driftsäkerhet och modern observability.</li><li>Svenska och engelska i tal och skrift.</li></ul><p><strong>Det är meriterande om du har erfarenhet av</strong></p><ul><li>Spacelift eller annan IaC-orkestrering.</li><li>Declarative Automation Bundles (tidigare Databricks Asset Bundles).</li><li>Dbt eller motsvarande transformationsverktyg</li><li>Integrationer mot ERP- eller HR-system.</li><li>Lakehouse-arkitektur, data governance och Unity Catalog.</li><li>Power BI och semantisk modellering.</li></ul><p>Vi lägger stor vikt vid din nyfikenhet, din problemlösningsförmåga och din vilja att utvecklas tillsammans med oss.</p><p><strong>Om AcadeMedia</strong></p><p>AcadeMedia är Europas största utbildningsföretag med verksamhet i stora delar av Europa. Genom våra förskolor, grundskolor, gymnasier och vuxenutbildningar bidrar vi varje dag till att utveckla utbildning för barn, unga och vuxna. Data &amp; Analytics-teamet arbetar centralt mot samtliga dessa verksamheter.</p><p><strong>Övrig information</strong></p><p><strong>Tjänstens omfattning och placering</strong>Tjänsten är en tillsvidareanställnin ...
#   'company_information': None,
#   'needs': None,
#   'requirements': None,
#   'conditions': None},
#  'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#   'label': 'Vanlig anställning',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#   'label': 'Fast månads- vecko- eller timlön',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_description': None,
#  'duration': {'concept_id': 'a7uU_j21_mkL',
#   'label': 'Tills vidare',
#   'legacy_ams_taxonomy_id': '1'},
#  'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#   'label': 'Heltid',
#   'legacy_ams_taxonomy_id': '1'},
#  'scope_of_work': {'min': 100, 'max': 100},
#  'access': None,
#  'employer': {'phone_number': None,
#   'email': None,
#   'url': None,
#   'organization_number': '5565688479',
#   'name': 'AcadeMedia Support AB',
#   'workplace': 'AcadeMedia Support'},
#  'application_details': {'information': None,
#   'reference': None,
#   'email': None,
#   'via_af': False,
#   'url': 'https://academedia.se/om-oss/jobba-hos-oss/lediga-jobb/?jobid=318459&ref=platsbankenv2',
#   'other': None},
#  'experience_required': True,
#  'access_to_own_car': False,
#  'driving_license_required': False,
#  'driving_license': None,
#  'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#   'label': 'Dataingenjör',
#   'legacy_ams_taxonomy_id': '7338'},
#  'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#   'label': 'Ingenjörer och tekniker inom elektroteknik',
#   'legacy_ams_taxonomy_id': '3113'},
#  'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#   'label': 'Yrken med teknisk inriktning',
#   'legacy_ams_taxonomy_id': '18'},
#  'workplace_model': {'concept_id': 'ZxwM_gtz_n61', 'label': 'Arbete på plats'},
#  'workplace_address': {'municipality': 'Stockholm',
#   'municipality_code': '0180',
#   'municipality_concept_id': 'AvNB_uwa_6n6',
#   'region': 'Stockholms län',
#   'region_code': '01',
#   'region_concept_id': 'CifL_Rzy_Mku',
#   'country': 'Sverige',
#   'country_code': '199',
#   'country_concept_id': 'i46j_HmG_v64',
#   'street_address': None,
#   'postcode': '11137',
#   'city': 'Stockholm',
#   'coordinates': [18.06149880255592, 59.33670594541106]},
#  'workplace_addresses': [{'municipality': 'Stockholm',
#    'municipality_code': '0180',
#    'municipality_concept_id': 'AvNB_uwa_6n6',
#    'region': 'Stockholms län',
#    'region_code': '01',
#    'region_concept_id': 'CifL_Rzy_Mku',
#    'country': 'Sverige',
#    'country_code': '199',
#    'country_concept_id': 'i46j_HmG_v64',
#    'street_address': None,
#    'postcode': '11137',
#    'city': 'Stockholm',
#    'coordinates': [18.06149880255592, 59.33670594541106]}],
#  'must_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'nice_to_have': {'skills': [],
#   'languages': [{'weight': 5,
#     'concept_id': 'zSLA_vw2_FXN',
#     'label': 'Svenska',
#     'legacy_ams_taxonomy_id': '502'},
#    {'weight': 5,
#     'concept_id': 'NVxJ_hLg_TYS',
#     'label': 'Engelska',
#     'legacy_ams_taxonomy_id': '283'}],
#   'work_experiences': [{'weight': 5,
#     'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'}],
#   'education': [],
#   'education_level': []},
#  'application_contacts': [],
#  'publication_date': '2026-09-15T16:31:31',
#  'last_publication_date': '2026-10-19T23:59:59',
#  'removed': False,
#  'removed_date': None,
#  'source_type': 'VIA_JOBPOSTING',
#  'timestamp': 1789482691256}
